# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import statsmodels.api as sm
import itertools

# plt.style.use('fivethirtyeight')
# %matplotlib inline
# from matplotlib.pylab import rcParams
# rcParams['figure.figsize'] = 13, 8

import plotly.express as px

# import collections

import functions as fun



import datetime
import seaborn as sns
sns.set()

# %%
# %load_ext autoreload
# %autoreload

# %%
z_df = pd.read_csv('zillow_data.csv')
z_df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %% [markdown]
# # Data of all regions/cities and states with values of homes for each month from 1996 to 2018

# %% [markdown]
# # Let's look at Chicago because:
# - urbanization and public transportation
# - possiblility of looking at homes closest to train lines?
# - walkscore?
# - population and growth?

# %%
df_chicago = z_df.loc[z_df['City']=='Chicago']
df_chicago.head()
# Out:
#     RegionID  RegionName     City State    Metro CountyName  SizeRank  \
# 0      84654       60657  Chicago    IL  Chicago       Cook         1
# 3      84616       60614  Chicago    IL  Chicago       Cook         4
# 7      84640       60640  Chicago    IL  Chicago       Cook         8
# 16     84646       60647  Chicago    IL  Chicago       Cook        17
# 19     84620       60618  Chicago    IL  Chicago       Cook        20
#
#      1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  \
# 0   334200.0  335400.0  336500.0  ...  1005500  1007500  1007800  1009600
# 3   498100.0  500900.0  503100.0  ...  1289800  1287700  1287400  1291500
# 7   216500.0  216700.0  216900.0  ...   798000   787100   776100   774900
# 16  122700.0  122800.0  122800.0  ...   459600   461400   464300   466500
# 19  142600.0  143100.0  143400.0  ...   462700   461200   459900   459200
#
#     2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1013300  1018700  1024400  1030700  1033800  1030600
# 3   1296600  1299000  1302700  1306400  1308500  1307000
# 7    777900   777900   778500   780500   782800   782800
# 16   467900   470600   474500   475100   472600   470200
# 19   458700   457900   457400   459000   462500   464300
#
# [5 rows x 272 columns]

# %%
# Let's make a back up to be safe from overriding
df_chicago_copy = z_df.loc[z_df['City']=='Chicago']
# df_chicago_copy

# %%
##Rename RegionName to ZipCode
df_chicago.rename(columns={'RegionName': 'ZipCode'}, inplace=True)
df_chicago.head()
# Out:
#     RegionID  ZipCode     City State    Metro CountyName  SizeRank   1996-04  \
# 0      84654    60657  Chicago    IL  Chicago       Cook         1  334200.0
# 3      84616    60614  Chicago    IL  Chicago       Cook         4  498100.0
# 7      84640    60640  Chicago    IL  Chicago       Cook         8  216500.0
# 16     84646    60647  Chicago    IL  Chicago       Cook        17  122700.0
# 19     84620    60618  Chicago    IL  Chicago       Cook        20  142600.0
#
#      1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 0   335400.0  336500.0  ...  1005500  1007500  1007800  1009600  1013300
# 3   500900.0  503100.0  ...  1289800  1287700  1287400  1291500  1296600
# 7   216700.0  216900.0  ...   798000   787100   776100   774900   777900
# 16  122800.0  122800.0  ...   459600   461400   464300   466500   467900
# 19  143100.0  143400.0  ...   462700   461200   459900   459200   458700
#
#     2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1018700  1024400  1030700  1033800  1030600
# 3   1299000  1302700  1306400  1308500  1307000
# 7    777900   778500   780500   782800   782800
# 16   470600   474500   475100   472600   470200
# 19   457900   457400   459000   462500   464300
#
# [5 rows x 272 columns]

# %%
# make sure all zip codes are Cook County 
df_chicago['CountyName'].nunique()
# Out:
# 1

# %%
df_chicago['ZipCode'].nunique()
# Out:
# 41

# %% [markdown]
# #### Decided to drop all null values because one of the zip codes didn't have data until 2013 and that was about it so I just got rid of it because it really wasn't a zip code I felt we could predict for.

# %%
df_chicago.isna().sum()
# Out:
# RegionID    0
# ZipCode     0
# City        0
# State       0
# Metro       0
#            ..
# 2017-12     0
# 2018-01     0
# 2018-02     0
# 2018-03     0
# 2018-04     0
# Length: 272, dtype: int64

# %%
df_chicago.dropna(inplace=True)

# %%
df_chicago['ZipCode'].nunique()
# Out:
# 40

# %% [markdown]
# #### Just to double check - we only lost one zip code there

# %% [markdown]
# ### So to narrow down zip codes I decided to use Zillow's size rank score which is based on population - the lower the score = higher the population density
# ### For my business case I wanted to filter and use the more urbanized zip codes because:
# - Walkability Scores
# - Public Transportation
# - Low Carbon Emissions
# - Restaurants within 10 block radius (?)
# - ?? more ??
#
# #### I don't have a set top % I want to use - I'm basically just playing with the quantile range to see how many zip codes are returned that seem to be a fair amount to use for modeling/forecasting.

# %%
# filter zipcodes with a size rank in the top 75% (highly urbanized zipcodes)

urban = df_chicago.SizeRank.quantile(q=0.75)
print(f'Size Rank 75% cutoff value: {urban}')
top_zips_df = df_chicago[df_chicago['SizeRank'] < urban]
print(f'Amount of zip codes: {top_zips_df.ZipCode.nunique()}')
top_zips_df.head()
# Out:
# Size Rank 75% cutoff value: 2083.5
# Amount of zip codes: 30
#     RegionID  ZipCode     City State    Metro CountyName  SizeRank   1996-04  \
# 0      84654    60657  Chicago    IL  Chicago       Cook         1  334200.0
# 3      84616    60614  Chicago    IL  Chicago       Cook         4  498100.0
# 7      84640    60640  Chicago    IL  Chicago       Cook         8  216500.0
# 16     84646    60647  Chicago    IL  Chicago       Cook        17  122700.0
# 19     84620    60618  Chicago    IL  Chicago       Cook        20  142600.0
#
#      1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 0   335400.0  336500.0  ...  1005500  1007500  1007800  1009600  1013300
# 3   500900.0  503100.0  ...  1289800  1287700  1287400  1291500  1296600
# 7   216700.0  216900.0  ...   798000   787100   776100   774900   777900
# 16  122800.0  122800.0  ...   459600   461400   464300   466500   467900
# 19  143100.0  143400.0  ...   462700   461200   459900   459200   458700
#
#     2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1018700  1024400  1030700  1033800  1030600
# 3   1299000  1302700  1306400  1308500  1307000
# 7    777900   778500   780500   782800   782800
# 16   470600   474500   475100   472600   470200
# 19   457900   457400   459000   462500   464300
#
# [5 rows x 272 columns]

# %%
top_zips_df.to_csv('top_zips_with_all_columns.csv', index=False)

# %%
# get locations
# best_zips = list(top_zips_df.ZipCode.values)
# for i in best_zips:
#     city = top_zips_df[top_zips_df['ZipCode']==i].City.values[0]
#     state = top_zips_df[top_zips_df['ZipCode']==i].State.values[0]
#     region = top_zips_df[top_zips_df['ZipCode']==i].RegionID.values[0]
#     print(f'ZipCode: {i}\n Location: {city}, {state}\n')
#     print(f'ZipCode: {i}\n Region ID: {region}\n')

# %%
# making a dictionary of zip codes with their corresponding region id's 
# because I may need them for plotting or identification of zip code location
# region
region_dict = {}
zip_list = top_zips_df.ZipCode.unique()
for i in zip_list:
    region = top_zips_df[top_zips_df['ZipCode']==i].RegionID.values[0]
    region_dict[i] = region

# %%
region_dict[60657]
# Out:
# 84654

# %% [markdown]
# ### I wanted to drop some unnecessary columns for plotting only - I am not ready to melt the dataframe or make this a time series yet

# %%
plotting_df = top_zips_df.drop(['RegionID', 'City', 'State', 'Metro', 'CountyName', 'SizeRank'], axis=1)
plotting_df.head()
# Out:
#     ZipCode   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0     60657  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 3     60614  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 7     60640  216500.0  216700.0  216900.0  217000.0  217100.0  217200.0
# 16    60647  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0
# 19    60618  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0
#
#      1996-10   1996-11   1996-12  ...  2017-07  2017-08  2017-09  2017-10  \
# 0   340400.0  341300.0  342600.0  ...  1005500  1007500  1007800  1009600
# 3   505300.0  504200.0  503600.0  ...  1289800  1287700  1287400  1291500
# 7   217500.0  217900.0  218600.0  ...   798000   787100   776100   774900
# 16  121500.0  120900.0  120500.0  ...   459600   461400   464300   466500
# 19  141300.0  140100.0  139000.0  ...   462700   461200   459900   459200
#
#     2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1013300  1018700  1024400  1030700  1033800  1030600
# 3   1296600  1299000  1302700  1306400  1308500  1307000
# 7    777900   777900   778500   780500   782800   782800
# 16   467900   470600   474500   475100   472600   470200
# 19   458700   457900   457400   459000   462500   464300
#
# [5 rows x 266 columns]

# %%
## Reset index 
plot_df = plotting_df.reset_index(drop=True)
plot_df.head()
# Out:
#    ZipCode   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0    60657  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 1    60614  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 2    60640  216500.0  216700.0  216900.0  217000.0  217100.0  217200.0
# 3    60647  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0
# 4    60618  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0
#
#     1996-10   1996-11   1996-12  ...  2017-07  2017-08  2017-09  2017-10  \
# 0  340400.0  341300.0  342600.0  ...  1005500  1007500  1007800  1009600
# 1  505300.0  504200.0  503600.0  ...  1289800  1287700  1287400  1291500
# 2  217500.0  217900.0  218600.0  ...   798000   787100   776100   774900
# 3  121500.0  120900.0  120500.0  ...   459600   461400   464300   466500
# 4  141300.0  140100.0  139000.0  ...   462700   461200   459900   459200
#
#    2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1013300  1018700  1024400  1030700  1033800  1030600
# 1  1296600  1299000  1302700  1306400  1308500  1307000
# 2   777900   777900   778500   780500   782800   782800
# 3   467900   470600   474500   475100   472600   470200
# 4   458700   457900   457400   459000   462500   464300
#
# [5 rows x 266 columns]

# %%
## change zipcodes to string
plot_df["ZipCode"] = plot_df["ZipCode"].astype(str)

# %%
## change values to integer

# chicago_plot = chicago_plot.astype(int)

# %%
## transpose dates to rows
plot_df = plot_df.transpose()
plot_df.head()
# Out:
#              0       1       2       3       4       5      6       7      8   \
# ZipCode   60657   60614   60640   60647   60618   60613  60629   60625  60619
# 1996-04  334200  498100  216500  122700  142600  297900  93400  148900  76400
# 1996-05  335400  500900  216700  122800  143100  300400  94100  149300  77000
# 1996-06  336500  503100  216900  122800  143400  302600  94600  149600  77400
# 1996-07  337600  504600  217000  122700  143300  304700  94800  149700  77700
#
#              9   ...      20      21      22     23      24      25      26  \
# ZipCode   60610  ...   60638   60639   60630  60643   60632   60605   60645
# 1996-04  435200  ...  127400  111200  150600  86400   99600  293500  164900
# 1996-05  435200  ...  128300  111900  151600  87200  100100  293000  165400
# 1996-06  435100  ...  129000  112300  152300  87600  100400  292500  165700
# 1996-07  434600  ...  129100  112500  152600  87800  100400  291700  165600
#
#             27      28      29
# ZipCode  60651   60653   60654
# 1996-04  74700  116900  510000
# 1996-05  75100  115700  510200
# 1996-06  75400  114500  510100
# 1996-07  75600  113300  509600
#
# [5 rows x 30 columns]

# %%
## Renaming columns
new_header = plot_df.iloc[0] ## grab first row for new header
plot_df = plot_df[1:] ## take all data after first row
plot_df.columns = new_header ## reassign all columns to zipcodes

# %%
plot_df.head()
# Out:
# ZipCode   60657   60614   60640   60647   60618   60613  60629   60625  60619  \
# 1996-04  334200  498100  216500  122700  142600  297900  93400  148900  76400
# 1996-05  335400  500900  216700  122800  143100  300400  94100  149300  77000
# 1996-06  336500  503100  216900  122800  143400  302600  94600  149600  77400
# 1996-07  337600  504600  217000  122700  143300  304700  94800  149700  77700
# 1996-08  338500  505500  217100  122400  142900  306600  94700  149700  77700
#
# ZipCode   60610  ...   60638   60639   60630  60643   60632   60605   60645  \
# 1996-04  435200  ...  127400  111200  150600  86400   99600  293500  164900
# 1996-05  435200  ...  128300  111900  151600  87200  100100  293000  165400
# 1996-06  435100  ...  129000  112300  152300  87600  100400  292500  165700
# 1996-07  434600  ...  129100  112500  152600  87800  100400  291700  165600
# 1996-08  433900  ...  128900  112500  152400  87700  100300  290900  165400
#
# ZipCode  60651   60653   60654
# 1996-04  74700  116900  510000
# 1996-05  75100  115700  510200
# 1996-06  75400  114500  510100
# 1996-07  75600  113300  509600
# 1996-08  75600  112300  508800
#
# [5 rows x 30 columns]

# %%
# plot_df.plot()
# plt.title('Home Value Span for Chicago Zip Codes with Top 75% Urbanization')
# plt.xlabel('time')
# plt.ylabel('median home value')
# plt.legend("")
# plt.show()

# %%
fun.plot(plot_df)
# plt.title('Home Value Span for Chicago Zip Codes with Top 75% Urbanization')

# %% [markdown]
# ### Obviously the economic crash of 2008 had a huge unforeseen affect on housing values.
# #### Because of this I decided to take only data from 2011 on where it looks to have started to straighten back out.

# %%
plot_df = plot_df.loc[plot_df.index >= '2011-01']

# %%
plot_df
# Out:
# ZipCode    60657    60614   60640   60647   60618    60613   60629   60625  \
# 2011-01   729300   923000  600000  286500  317400   722000  125300  337500
# 2011-02   730200   925000  601600  285800  316300   723400  124300  339500
# 2011-03   730700   923300  599700  283800  314000   724200  123100  340600
# 2011-04   730000   916600  590500  282100  311400   722300  121500  340500
# 2011-05   730100   912400  578900  281700  308200   724100  119800  339500
# ...          ...      ...     ...     ...     ...      ...     ...     ...
# 2017-12  1018700  1299000  777900  470600  457900  1041300  162600  463100
# 2018-01  1024400  1302700  778500  474500  457400  1051300  163500  464100
# 2018-02  1030700  1306400  780500  475100  459000  1059300  164000  464200
# 2018-03  1033800  1308500  782800  472600  462500  1060200  164000  463200
# 2018-04  1030600  1307000  782800  470200  464300  1055300  163800  461100
#
# ZipCode   60619    60610  ...   60638   60639   60630   60643   60632   60605  \
# 2011-01  122200   749200  ...  172100  142700  228100  134600  133300  555800
# 2011-02  122200   748600  ...  171400  141600  227200  133400  132500  557400
# 2011-03  122500   747300  ...  170100  141200  225900  132300  131600  557600
# 2011-04  123300   745300  ...  168400  141300  224200  131200  130300  556500
# 2011-05  123500   744200  ...  166700  141500  223100  130300  129000  559100
# ...         ...      ...  ...     ...     ...     ...     ...     ...     ...
# 2017-12  127800  1045700  ...  209000  226100  301200  145700  164300  722000
# 2018-01  127100  1050800  ...  210200  228700  302500  145100  164700  718900
# 2018-02  126800  1050400  ...  212000  231400  304900  145300  165200  715000
# 2018-03  128000  1045000  ...  213500  232700  307600  145500  166100  712500
# 2018-04  129600  1039700  ...  214000  232600  308700  144500  166700  709500
#
# ZipCode   60645   60651   60653    60654
# 2011-01  289000  120100  276800   944900
# 2011-02  288700  122000  272900   948800
# 2011-03  287300  123200  269300   953700
# 2011-04  284800  123300  266700   957500
# 2011-05  281400  123100  262500   961000
# ...         ...     ...     ...      ...
# 2017-12  360200  142900  332300  1442400
# 2018-01  360600  145200  334800  1452900
# 2018-02  361400  148300  335500  1464600
# 2018-03  361600  150300  334400  1472400
# 2018-04  360400  150900  333000  1474500
#
# [88 rows x 30 columns]

# %%
fun.plot(plot_df)
# plt.title('Home Values for Chicago Zip Codes from 2011-2018')
# plt.xlabel('time')
# plt.ylabel('median home value')
# plt.legend("")
# plt.show()

# %% [markdown]
# ## This looks much better!
# ### The zip code that randomly started in 2013 is gone as well.

# %% [markdown]
# ### I originally thought of modeling ROI instead of median value - but I am still unsure.
# - Since the data is already preprocessed - I suppose I could make the ROI dataframe and test it against median values.
# - I think the ROI will help with the issue of stationary data when modeling as well as good for forecasting and visualizations??

# %%
# save our filtered dataframe for future use and to prevent overriding
# NO INDEX with function ran !!
# fun.get_index_ready(plot_df)
plot_df.to_csv('chi_plot.csv', index=False)

# %%
# chi_plot.info()

# %%
# plot_df.head()

# %% [markdown]
# ### I will make the ROI data set from the dataframe we saved above.

# %% [markdown]
# ### But first I want to take the average of every year so as not to lose any valuable information.

# %%
plotting_df.head()
# Out:
#     ZipCode   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0     60657  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 3     60614  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 7     60640  216500.0  216700.0  216900.0  217000.0  217100.0  217200.0
# 16    60647  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0
# 19    60618  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0
#
#      1996-10   1996-11   1996-12  ...  2017-07  2017-08  2017-09  2017-10  \
# 0   340400.0  341300.0  342600.0  ...  1005500  1007500  1007800  1009600
# 3   505300.0  504200.0  503600.0  ...  1289800  1287700  1287400  1291500
# 7   217500.0  217900.0  218600.0  ...   798000   787100   776100   774900
# 16  121500.0  120900.0  120500.0  ...   459600   461400   464300   466500
# 19  141300.0  140100.0  139000.0  ...   462700   461200   459900   459200
#
#     2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1013300  1018700  1024400  1030700  1033800  1030600
# 3   1296600  1299000  1302700  1306400  1308500  1307000
# 7    777900   777900   778500   780500   782800   782800
# 16   467900   470600   474500   475100   472600   470200
# 19   458700   457900   457400   459000   462500   464300
#
# [5 rows x 266 columns]

# %%
roi_df = plotting_df.copy()
roi_df.head()
# Out:
#     ZipCode   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0     60657  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 3     60614  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 7     60640  216500.0  216700.0  216900.0  217000.0  217100.0  217200.0
# 16    60647  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0
# 19    60618  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0
#
#      1996-10   1996-11   1996-12  ...  2017-07  2017-08  2017-09  2017-10  \
# 0   340400.0  341300.0  342600.0  ...  1005500  1007500  1007800  1009600
# 3   505300.0  504200.0  503600.0  ...  1289800  1287700  1287400  1291500
# 7   217500.0  217900.0  218600.0  ...   798000   787100   776100   774900
# 16  121500.0  120900.0  120500.0  ...   459600   461400   464300   466500
# 19  141300.0  140100.0  139000.0  ...   462700   461200   459900   459200
#
#     2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1013300  1018700  1024400  1030700  1033800  1030600
# 3   1296600  1299000  1302700  1306400  1308500  1307000
# 7    777900   777900   778500   780500   782800   782800
# 16   467900   470600   474500   475100   472600   470200
# 19   458700   457900   457400   459000   462500   464300
#
# [5 rows x 266 columns]

# %%
# %load_ext autoreload
# %autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
year_list = ['1996', '1997','1998', '1999','2000', '2001','2002',
             '2003','2004','2005','2006','2007','2008','2009',
             '2010','2011', '2012', '2013', '2014', '2015', 
             '2016', '2017', '2018']

# %%
for year in year_list:
    fun.get_mean_year(roi_df, year)

# %%
roi_df.head()
# Out:
#     ZipCode   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0     60657  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 3     60614  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 7     60640  216500.0  216700.0  216900.0  217000.0  217100.0  217200.0
# 16    60647  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0
# 19    60618  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0
#
#      1996-10   1996-11   1996-12  ...     2009    2010    2011    2012  \
# 0   340400.0  341300.0  342600.0  ...   790743  760244  732548  761040
# 3   505300.0  504200.0  503600.0  ...  1014667  964985  920240  965996
# 7   217500.0  217900.0  218600.0  ...   654189  612099  582324  552544
# 16  121500.0  120900.0  120500.0  ...   326094  295397  283307  282759
# 19  141300.0  140100.0  139000.0  ...   349025  325650  305273  304986
#
#        2013     2014     2015     2016     2017     2018
# 0    834854   881141   918897   975076  1001805  1028402
# 3   1078377  1163246  1196334  1246987  1286311  1304973
# 7    576204   620609   687837   736271   776390   780645
# 16   321985   335174   369550   429273   457312   472169
# 19   346769   371575   381782   433078   461936   460633
#
# [5 rows x 289 columns]

# %% [markdown]
# #### Get rid of all the months since we now have the average value for each year

# %%
for col in roi_df:
    if '-' in col:
        roi_df.drop([col], inplace=True, axis=1)
roi_df.head()
# Out:
#     ZipCode    1996    1997    1998    1999    2000    2001    2002    2003  \
# 0     60657  345921  352942  396505  466646  565227  653381  711351  744140
# 3     60614  512123  499496  561259  651321  750713  853123  931631  993753
# 7     60640  223373  227483  260710  313352  379441  439705  488811  525081
# 16    60647  125795  119906  133649  153535  184238  222121  246892  275076
# 19    60618  145467  133178  150818  175660  213341  256170  274249  298255
#
#        2004  ...     2009    2010    2011    2012     2013     2014     2015  \
# 0    783799  ...   790743  760244  732548  761040   834854   881141   918897
# 3   1039340  ...  1014667  964985  920240  965996  1078377  1163246  1196334
# 7    559548  ...   654189  612099  582324  552544   576204   620609   687837
# 16   305892  ...   326094  295397  283307  282759   321985   335174   369550
# 19   340297  ...   349025  325650  305273  304986   346769   371575   381782
#
#        2016     2017     2018
# 0    975076  1001805  1028402
# 3   1246987  1286311  1304973
# 7    736271   776390   780645
# 16   429273   457312   472169
# 19   433078   461936   460633
#
# [5 rows x 24 columns]

# %%
# roi_all_years = roi_df.copy()

# %%
# # flipping it for our plot function
# plot_roi = roi_df.transpose()
# ## Renaming columns
# new_header = plot_roi.iloc[0] ## grab first row for new header
# plot_roi = plot_roi[1:] ## take all data after first row
# plot_roi.columns = new_header ## reassign all columns to zipcodes

# %% [markdown]
# #### Below is 1996 to 2011 - I just wanted to confirm that the 2008 economic crash looked the same with the averages for the years and it does.

# %%
# average value for each year 
fun.plot(plot_roi)

# %%
# roi_all_years.to_csv('roi_avg_all_years.csv', index=False)

# %%
# roi_2011_years = roi_all_years.copy()
# # roi_2011_years just in case
# # eliminating all years before 2011 to account for 2008 crash
# for col in roi_2011_years.columns:
#     if col < '2011':
#         roi_2011_years.drop([col], inplace=True, axis=1)

# roi_2011_years.head()
# Out:
#     ZipCode    2011    2012     2013     2014     2015     2016     2017  \
# 0     60657  732548  761040   834854   881141   918897   975076  1001805
# 3     60614  920240  965996  1078377  1163246  1196334  1246987  1286311
# 7     60640  582324  552544   576204   620609   687837   736271   776390
# 16    60647  283307  282759   321985   335174   369550   429273   457312
# 19    60618  305273  304986   346769   371575   381782   433078   461936
#
#        2018
# 0   1028402
# 3   1304973
# 7    780645
# 16   472169
# 19   460633

# %%
# roi_2011_years.to_csv('roi_avg_2011.csv', index=False)

# %%
# eliminating all years before 2011 to account for 2008 crash
for col in roi_df.columns:
    if col < '2011':
        roi_df.drop([col], inplace=True, axis=1)

roi_df.head()
# Out:
#     ZipCode    2011    2012     2013     2014     2015     2016     2017  \
# 0     60657  732548  761040   834854   881141   918897   975076  1001805
# 3     60614  920240  965996  1078377  1163246  1196334  1246987  1286311
# 7     60640  582324  552544   576204   620609   687837   736271   776390
# 16    60647  283307  282759   321985   335174   369550   429273   457312
# 19    60618  305273  304986   346769   371575   381782   433078   461936
#
#        2018
# 0   1028402
# 3   1304973
# 7    780645
# 16   472169
# 19   460633

# %%
roi_df['2012-01'] = fun.get_return_rate('2011', '2012', roi_df)
roi_df['2013-01'] = fun.get_return_rate('2012', '2013', roi_df)
roi_df['2014-01'] = fun.get_return_rate('2013', '2014', roi_df) 
roi_df['2015-01'] = fun.get_return_rate('2014', '2015', roi_df)
roi_df['2016-01'] = fun.get_return_rate('2015', '2016', roi_df) 
roi_df['2017-01'] = fun.get_return_rate('2016', '2017', roi_df) 
roi_df['2018-01'] = fun.get_return_rate('2017', '2018', roi_df) 
roi_df.drop(['2011', '2012', '2013', '2014', '2015', '2016', '2017',
       '2018'], inplace=True, axis=1)
roi_df.head()
# Out:
#     ZipCode   2012-01    2013-01   2014-01    2015-01    2016-01   2017-01  \
# 0     60657  3.889438   9.699096  5.544323   4.284899   6.113743  2.741222
# 3     60614  4.972181  11.633692  7.870068   2.844454   4.234018  3.153521
# 7     60640 -5.113992   4.282012  7.706472  10.832585   7.041494  5.448945
# 16    60647 -0.193430  13.872591  4.096154  10.256165  16.161007  6.531741
# 19    60618 -0.094014  13.699973  7.153465   2.746956  13.435940  6.663465
#
#      2018-01
# 0   2.654908
# 3   1.450816
# 7   0.548049
# 16  3.248767
# 19 -0.282074

# %%
# test_mean = roi_df.groupby('ZipCode')
# test_mean.head()

# %%
roi_df.index.nunique()
# Out:
# 30

# %%
# # Chicago Zip Code % ROI from yearly average home values
# plt.figure(figsize = (13,8))
# plt.bar(mean_roi.index, roi_df['2018-01'], color='purple')
# plt.title('TOP Chicago Zip Codes by % ROI in 2018')
# plt.xlabel('Zip Code')
# plt.xticks(rotation=60)
# plt.ylabel('% ROI')
# plt.show()

# %%
# roi_df.to_csv('roi_from_averages.csv', index=False)

# %%
# mean_roi = roi_df.groupby('ZipCode').mean()
# mean_roi.head()

# %%
# no index with function!
# fun.get_index_ready(mean_roi)
# mean_roi.to_csv('mean_roi_from_averages.csv', index=False)

# %%
# # filter zipcodes % ROI over 3

# top_mean = mean_roi['2018-01'].quantile(q=0.50)
# print(f'2018 ROI 20% cutoff value: {top_mean}')
# top_mean_df = mean_roi[mean_roi['2018-01'] > top_mean]
# print(f'Amount of zip codes: {top_mean_df.index.nunique()}')
# top_mean_df.head()

# %%
date_roi = df_roi.groupby('ZipCode').mean()
date_roi.head()
# Out:
#          2012-01-01  2013-01-01  2014-01-01  2015-01-01  2016-01-01  \
# ZipCode
# 60605      3.850306   -1.351351    6.515630    7.419621   -5.587107
# 60608     -6.785317   -0.059666    2.328358    7.176196   14.589004
# 60610      2.135611    6.246733   15.055351   -1.614283    3.433663
# 60613      2.160665    5.097614    5.030960    3.979366   10.441767
# 60614      0.639220    8.332436   13.862665    2.670623    4.615777
#
#          2017-01-01  2018-01-01
# ZipCode
# 60605     12.225654    4.143126
# 60608     16.152019   -5.480573
# 60610      7.710894    2.487077
# 60613      6.010695    6.063358
# 60614      3.404567    2.365237

# %%
date_roi.head()
# Out:
#          2012-01-01  2013-01-01  2014-01-01  2015-01-01  2016-01-01  \
# ZipCode
# 60605      3.850306   -1.351351    6.515630    7.419621   -5.587107
# 60608     -6.785317   -0.059666    2.328358    7.176196   14.589004
# 60610      2.135611    6.246733   15.055351   -1.614283    3.433663
# 60613      2.160665    5.097614    5.030960    3.979366   10.441767
# 60614      0.639220    8.332436   13.862665    2.670623    4.615777
#
#          2017-01-01  2018-01-01
# ZipCode
# 60605     12.225654    4.143126
# 60608     16.152019   -5.480573
# 60610      7.710894    2.487077
# 60613      6.010695    6.063358
# 60614      3.404567    2.365237

# %%
date_roi.index.nunique()
# Out:
# 30

# %%
zip_roi = date_roi.transpose()
zip_roi
# Out:
# ZipCode         60605      60608      60610      60613      60614      60615  \
# 2012-01-01   3.850306  -6.785317   2.135611   2.160665   0.639220  -1.798658
# 2013-01-01  -1.351351  -0.059666   6.246733   5.097614   8.332436   1.995626
# 2014-01-01   6.515630   2.328358  15.055351   5.030960  13.862665  10.881801
# 2015-01-01   7.419621   7.176196  -1.614283   3.979366   2.670623   2.344694
# 2016-01-01  -5.587107  14.589004   3.433663  10.441767   4.615777   0.212565
# 2017-01-01  12.225654  16.152019   7.710894   6.010695   3.404567  12.773981
# 2018-01-01   4.143126  -5.480573   2.487077   6.063358   2.365237  -5.935214
#
# ZipCode         60616      60618      60619      60620  ...      60641  \
# 2012-01-01  -3.564014  -7.687461 -10.883797 -14.263323  ...  -9.584828
# 2013-01-01   5.238608  10.750853   4.132231  -3.930530  ...   1.077098
# 2014-01-01  11.012615  13.528505 -11.287478  -9.609895  ...  21.424565
# 2015-01-01  -2.395577   1.275787  20.874751   2.631579  ...   6.882217
# 2016-01-01   3.807426   7.343876  -8.717105  26.974359  ...  10.025929
# 2017-01-01   6.183692  15.955056  15.405405  -2.504039  ...   5.380990
# 2018-01-01  -0.057094  -1.507321  -0.780640   5.799503  ...   7.454342
#
# ZipCode        60643      60645      60647      60649      60651      60653  \
# 2012-01-01 -5.423477  -8.858131  -0.837696 -12.365591 -12.905912 -18.099711
# 2013-01-01  5.970149   4.024298   5.491024  12.883436  -8.699809   6.528452
# 2014-01-01 -3.780578  13.832117   8.375042   3.464674 -11.623037   1.532091
# 2015-01-01  0.924499   2.404617   7.881773   3.939593  16.587678   5.954323
# 2016-01-01  6.030534   3.443957  13.727169 -19.330385  34.349593  10.854503
# 2017-01-01  2.663787   6.295400  11.769134  18.872357   2.269289   8.125000
# 2018-01-01  1.753156   2.676538   6.533453   1.515152   7.396450   7.514451
#
# ZipCode         60654     60657      60660
# 2012-01-01   5.672558  1.151789  -8.932310
# 2013-01-01   2.203305  8.756947   5.287356
# 2014-01-01  14.130328  6.718185   0.460941
# 2015-01-01   8.027818  4.298061  13.523304
# 2016-01-01   3.703704  6.662934   8.721549
# 2017-01-01   5.004598  4.671916   4.343573
# 2018-01-01   6.043354  2.748245  -2.212638
#
# [7 rows x 30 columns]

# %%
# fun.plot(zip_roi)

# %%
zip_roi.plot(figsize=(13, 8))
plt.xlabel('Years')
plt.ylabel('Percent ROI')
plt.title('Chicago Percent Yearly ROI for Selected Zip Codes')
plt.show()

# %% [markdown]
# ### Let's filter out only the zip codes with an ROI percentage over 3% in 2018
# #### We will do this for both the roi df and the values df

# %%
# filter zipcodes with a size rank in the top 75% (highly urbanized zipcodes)

top_percent = date_roi['2018-01-01'].quantile(q=0.50)
print(f'2018 ROI 20% cutoff value: {top_percent}')
top_percent_df = date_roi[date_roi['2018-01-01'] > top_percent]
print(f'Amount of zip codes: {top_percent_df.index.nunique()}')
top_percent_df.head()
# Out:
# 2018 ROI 20% cutoff value: 3.9929763994008263
# Amount of zip codes: 15
#          2012-01-01  2013-01-01  2014-01-01  2015-01-01  2016-01-01  \
# ZipCode
# 60605      3.850306   -1.351351    6.515630    7.419621   -5.587107
# 60613      2.160665    5.097614    5.030960    3.979366   10.441767
# 60620    -14.263323   -3.930530   -9.609895    2.631579   26.974359
# 60622     -0.037545    0.995305   10.245444    3.896104   14.853896
# 60625     -3.259259    1.715161   13.309244    1.062982    4.207205
#
#          2017-01-01  2018-01-01
# ZipCode
# 60605     12.225654    4.143126
# 60613      6.010695    6.063358
# 60620     -2.504039    5.799503
# 60622      6.855124    8.373016
# 60625     11.052233    5.453306

# %%
top_percent_df
# Out:
#          2012-01-01  2013-01-01  2014-01-01  2015-01-01  2016-01-01  \
# ZipCode
# 60605      3.850306   -1.351351    6.515630    7.419621   -5.587107
# 60613      2.160665    5.097614    5.030960    3.979366   10.441767
# 60620    -14.263323   -3.930530   -9.609895    2.631579   26.974359
# 60622     -0.037545    0.995305   10.245444    3.896104   14.853896
# 60625     -3.259259    1.715161   13.309244    1.062982    4.207205
# 60629    -13.487630    4.243542    4.070796   11.309524    7.944996
# 60630     -5.655414    0.975836   10.216291    9.018789    5.208732
# 60634    -11.800610    0.230681   20.253165    7.799043    6.835331
# 60638    -10.052295   -3.940568   11.903161    2.463942    9.736070
# 60639     -2.172390    0.429799   12.553495    8.555133    8.814945
# 60641     -9.584828    1.077098   21.424565    6.882217   10.025929
# 60647     -0.837696    5.491024    8.375042    7.881773   13.727169
# 60651    -12.905912   -8.699809  -11.623037   16.587678   34.349593
# 60653    -18.099711    6.528452    1.532091    5.954323   10.854503
# 60654      5.672558    2.203305   14.130328    8.027818    3.703704
#
#          2017-01-01  2018-01-01
# ZipCode
# 60605     12.225654    4.143126
# 60613      6.010695    6.063358
# 60620     -2.504039    5.799503
# 60622      6.855124    8.373016
# 60625     11.052233    5.453306
# 60629      7.147912    7.992074
# 60630      5.314889    4.562738
# 60634      3.946822    4.116707
# 60638      6.948156    5.047476
# 60639     16.148069    5.635104
# 60641      5.380990    7.454342
# 60647     11.769134    6.533453
# 60651      2.269289    7.396450
# 60653      8.125000    7.514451
# 60654      5.004598    6.043354

# %%
# again we need THESE NEED AN INDEX - also they can be used for bar plots
top_percent_df.to_csv('top_roi_for_melting.csv')
date_roi.to_csv('chi_roi_for_melting.csv')

# %%
top_roi = top_percent_df.transpose()
top_roi.head()
# Out:
# ZipCode        60605      60613      60620      60622      60625      60629  \
# 2012-01-01  3.850306   2.160665 -14.263323  -0.037545  -3.259259 -13.487630
# 2013-01-01 -1.351351   5.097614  -3.930530   0.995305   1.715161   4.243542
# 2014-01-01  6.515630   5.030960  -9.609895  10.245444  13.309244   4.070796
# 2015-01-01  7.419621   3.979366   2.631579   3.896104   1.062982  11.309524
# 2016-01-01 -5.587107  10.441767  26.974359  14.853896   4.207205   7.944996
#
# ZipCode         60630      60634      60638      60639      60641      60647  \
# 2012-01-01  -5.655414 -11.800610 -10.052295  -2.172390  -9.584828  -0.837696
# 2013-01-01   0.975836   0.230681  -3.940568   0.429799   1.077098   5.491024
# 2014-01-01  10.216291  20.253165  11.903161  12.553495  21.424565   8.375042
# 2015-01-01   9.018789   7.799043   2.463942   8.555133   6.882217   7.881773
# 2016-01-01   5.208732   6.835331   9.736070   8.814945  10.025929  13.727169
#
# ZipCode         60651      60653      60654
# 2012-01-01 -12.905912 -18.099711   5.672558
# 2013-01-01  -8.699809   6.528452   2.203305
# 2014-01-01 -11.623037   1.532091  14.130328
# 2015-01-01  16.587678   5.954323   8.027818
# 2016-01-01  34.349593  10.854503   3.703704

# %%
# zip_roi.rename(columns={'Unnamed: 0': 'time'}, inplace=True)

# %%
# re-save our filtered dataframes for future use and to prevent overriding
# NO INDEX with function ran !!
# fun.get_index_ready(zip_roi)
# fun.get_index_ready(top_roi)
zip_roi.to_csv('roi_df_plotting.csv', index=False)
top_roi.to_csv('top_percent_roi_plotting.csv', index=False)

# %%
date_roi.head()
# Out:
#          2012-01-01  2013-01-01  2014-01-01  2015-01-01  2016-01-01  \
# ZipCode
# 60605      3.850306   -1.351351    6.515630    7.419621   -5.587107
# 60608     -6.785317   -0.059666    2.328358    7.176196   14.589004
# 60610      2.135611    6.246733   15.055351   -1.614283    3.433663
# 60613      2.160665    5.097614    5.030960    3.979366   10.441767
# 60614      0.639220    8.332436   13.862665    2.670623    4.615777
#
#          2017-01-01  2018-01-01
# ZipCode
# 60605     12.225654    4.143126
# 60608     16.152019   -5.480573
# 60610      7.710894    2.487077
# 60613      6.010695    6.063358
# 60614      3.404567    2.365237

# %%
# TOP Chicago Zip Codes by % ROI in 2018

plt.figure(figsize = (13,8))
plt.bar(date_roi.index, date_roi['2018-01-01'], color='purple')
plt.title('TOP Chicago Zip Codes by % ROI in 2018')
plt.xlabel('Zip Code')
plt.xticks(rotation=60)
plt.ylabel('% ROI')
plt.show()

# %%
# Chicago Zip Codes Over 3 % ROI in 2018

plt.figure(figsize = (13,8))
plt.bar(top_percent_df.index, top_percent_df['2018-01-01'], color='purple')
plt.title('Chicago Zip Codes Over 3 % ROI in 2018')
plt.xlabel('Zip Code')
plt.xticks(rotation=60)
plt.ylabel('% ROI')
plt.show()

# %%
top_percent_df.index.unique()
top_percent_df.index.nunique()
top_roi.columns.nunique()
# Out:
# 15

# %%
fun.plot(zip_roi)

# %%
fun.plot(top_roi)

# %%
import cufflinks as cf
cf.go_offline()
roi_chi.iplot(title="ROI of Chicago Homes 2011-2018",
                    xTitle="Year",
                    yTitle="Percent ROI",
                   shape=(13,8),
                    subplot_titles=True,
                    fill=True,)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>
#
#
#             <div id="53b2a271-481a-4e48-b3d4-05eba0011c5e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("53b2a271-481a-4e48-b3d4-05eba0011c5e")) {
#                     Plotly.newPlot(
#                         '53b2a271-481a-4e48-b3d4-05eba0011c5e',
#                         [{"fill": "tozeroy", "fillcolor": "rgba(255, 153, 51, 0.3)", "line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60613", "text": "", "type": "scatter", "x": ["2012-01-01", "2013-01-01", "2014-01-01", "2015-01-01", "2016-01-01", "2017-01-01", "2018-01-01"], "y": [2.160664819944598, 5.097613882863341, 5.030959752321981, 3.97936624907885, 10.441767068273093, 6.010695187165775, 6.063357546408394]}, {"fill": "tozeroy", "fillcolor": "rgba(55, 128, 191, 0.3)", "line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60625", "text": "", "type": "scatter", "x": ["2012-01-01", "2013-01-01", "2014-01-01", "2015-01-01", "2016-01-01", "2017-01-01", "2018-01-01"], "y": [-3.259259259259259, 1.7151607963246556, 13.309244203553147, 1.0629816635663034, 4.207204838285564, 11.05223315669947, 5.453306066802999]}, {"fill": "tozeroy", "fillcolor": "rgba(50, 171, 96, 0.3)", "line": {"color": "rgba(50, 171, 96, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60629", "text": "", "type": "scatter", "x": ["2012-01-01", "2013-01-01", "2014-01-01", "2015-01-01", "2016-01-01", "2017-01-01", "2018-01-01"], "y": [-13.487629688747008, 4.243542435424354, 4.070796460176991, 11.30952380952381, 7.944996180290298, 7.147912243453644, 7.9920739762219295]}, {"fill": "tozeroy", "fillcolor": "rgba(128, 0, 128, 0.3)", "line": {"color": "rgba(128, 0, 128, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60640", "text": "", "type": "scatter", "x": ["2012-01-01", "2013-01-01", "2014-01-01", "2015-01-01", "2016-01-01", "2017-01-01", "2018-01-01"], "y": [-5.783333333333333, -3.1664602865735003, 7.289002557544758, 12.753277711561385, 10.948353971609786, 2.014427657547298, 3.8692461641094065]}, {"fill": "tozeroy", "fillcolor": "rgba(219, 64, 82, 0.3)", "line": {"color": "rgba(219, 64, 82, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60647", "text": "", "type": "scatter", "x": ["2012-01-01", "2013-01-01", "2014-01-01", "2015-01-01", "2016-01-01", "2017-01-01", "2018-01-01"], "y": [-0.8376963350785341, 5.4910242872228086, 8.375041708375042, 7.8817733990147785, 13.72716894977169, 11.769134253450439, 6.533453075886843]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {" ...

# %%
# import cufflinks as cf
# cf.go_offline()
chi_filtered.iplot(title="Value of Chicago Homes 2011-2018",
                    xTitle="Year",
                    yTitle="Home Values",
                   shape=(13,8),
                    subplot_titles=True,
                    fill=True,)
# Out:
# <div>
#
#
#             <div id="0fb7c69f-c721-45ca-bf4d-b6366315b31e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("0fb7c69f-c721-45ca-bf4d-b6366315b31e")) {
#                     Plotly.newPlot(
#                         '0fb7c69f-c721-45ca-bf4d-b6366315b31e',
#                         [{"fill": "tozeroy", "fillcolor": "rgba(255, 153, 51, 0.3)", "line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60640", "text": "", "type": "scatter", "x": ["2011-01-01", "2011-02-01", "2011-03-01", "2011-04-01", "2011-05-01", "2011-06-01", "2011-07-01", "2011-08-01", "2011-09-01", "2011-10-01", "2011-11-01", "2011-12-01", "2012-01-01", "2012-02-01", "2012-03-01", "2012-04-01", "2012-05-01", "2012-06-01", "2012-07-01", "2012-08-01", "2012-09-01", "2012-10-01", "2012-11-01", "2012-12-01", "2013-01-01", "2013-02-01", "2013-03-01", "2013-04-01", "2013-05-01", "2013-06-01", "2013-07-01", "2013-08-01", "2013-09-01", "2013-10-01", "2013-11-01", "2013-12-01", "2014-01-01", "2014-02-01", "2014-03-01", "2014-04-01", "2014-05-01", "2014-06-01", "2014-07-01", "2014-08-01", "2014-09-01", "2014-10-01", "2014-11-01", "2014-12-01", "2015-01-01", "2015-02-01", "2015-03-01", "2015-04-01", "2015-05-01", "2015-06-01", "2015-07-01", "2015-08-01", "2015-09-01", "2015-10-01", "2015-11-01", "2015-12-01", "2016-01-01", "2016-02-01", "2016-03-01", "2016-04-01", "2016-05-01", "2016-06-01", "2016-07-01", "2016-08-01", "2016-09-01", "2016-10-01", "2016-11-01", "2016-12-01", "2017-01-01", "2017-02-01", "2017-03-01", "2017-04-01", "2017-05-01", "2017-06-01", "2017-07-01", "2017-08-01", "2017-09-01", "2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01"], "y": [600000, 601600, 599700, 590500, 578900, 570000, 570900, 574300, 575100, 575700, 575700, 573000, 565300, 555400, 549300, 552400, 555300, 551000, 545300, 546500, 552300, 555400, 552200, 547700, 547400, 549900, 556700, 566800, 574000, 581200, 588500, 591400, 591700, 591800, 589500, 587200, 587300, 588500, 589700, 593300, 602900, 614300, 624400, 634700, 644400, 651700, 657600, 662000, 662200, 663700, 668700, 673800, 677100, 682900, 688200, 692500, 698400, 708200, 717300, 726400, 734700, 739400, 736900, 732800, 731000, 730500, 730800, 735500, 740000, 740100, 741500, 746100, 749500, 754800, 765800, 776600, 785900, 795500, 798000, 787100, 776100, 774900, 777900, 777900, 778500, 780500, 782800, 782800]}, {"fill": "tozeroy", "fillcolor": "rgba(55, 128, 191, 0.3)", "line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60647", "text": "", "type": "scatter", "x": ["2011-01-01", "2011-02-01", "2011-03-01", "2011-04-01", "2011-05-01", "2011-06-01", "2011-07-01", "2011-08-01", "2011-09-01", "2011-10-01", "2011-11-01", "2011-12-01", "2012-01-01", "2012-02-01", "2012-03-01", "2012-04-01", "2012-05-01", "2012-06-01", "2012-07-01", "2012-08-01", "2012-09-01", "2012-10-01", "2012-11-01", "2012-12-01", "2013-01-01", "2013-02-01", "2013-03-01", "2013-04-01", "2013-05-01", "2013-06-01", "2013-07-01", "2013-08-01", "2013-09-01", "2013-10-01", "2013-11-01", "2013-12-01", "2014-01-01", "2014-02-01", "2014-03-01", "2014-04-01", "2014-05-01", "2014-06-01", "2014-07-01", "2014-08-01", "2014-09-01", "2014-10-01", "2014-11-01", "2014-12-01", "2015-01-01", "2015-02-01", "2015-03-01", "2015-04-01", "2015-05-01", "2015-06-01", "2015-07-01", "2015-08-01", "2015-09-01", "2015-10-01", "2015-11-01", "2015-12-01", "2016-01-01", "2016-02-01", "2016-03-01", "2016-04-01", "2016-05-01", "2016-06-01", "2016-07-01", "2016-08-01", "2016-09-01", "2016-10-01", "2016-11-01", "2016-12-01", "2017-01-01", "2017-02-01", "2017-03-01", "2017-04-01", "2017-05-01", "2017-06-01", "2017-07-01", "2017-08-01", "2017-09-01", "2017-10-01", "2017-11-01", "2017-12-01", "2018-01-01", "2018-02-01", "2018-03-01", "2018-04-01"], "y": [286500, 285800, 283800, 282100, 281700, 280500, 280000, 281400, 283400, 284700, 284300, 284400, 284100, 282100, 278500, 276200, 275600, 276200, 277700, 281400, 285600, 288700, 291600, 295300, 299700, 304600, 310800, 317200, 322100, 327300, 332800, 334100, 332100, 330400, 329000, 326700, 324800, 324300, 325600, 328000, 331100, 334500, 3 ...

# %% [markdown]
# ### Here is where I wanted to map out the ROI for all states

# %%
z_df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
map_df = pd.DataFrame()
map_df['State'] = z_df['State']
map_df['2018-04'] = z_df['2018-04']
map_df['2017-04'] = z_df['2017-04']
map_df.head()
# Out:
#   State  2018-04  2017-04
# 0    IL  1030600   989200
# 1    TX   321800   304400
# 2    TX   329900   320000
# 3    IL  1307000  1282500
# 4    TX   121500   118000

# %%
map_df['2018-04-01'] = fun.get_return_rate('2017-04', '2018-04', map_df)

# %%
map_df.head()
# Out:
#   State  2018-04  2017-04  2018-04-01
# 0    IL  1030600   989200    0.041852
# 1    TX   321800   304400    0.057162
# 2    TX   329900   320000    0.030937
# 3    IL  1307000  1282500    0.019103
# 4    TX   121500   118000    0.029661

# %%
map_df = map_df.groupby('State').mean()*100

# %%
map_df.reset_index(inplace=True)

# %%
map_df.head()
# Out:
#   State       2018-04       2017-04  2018-04-01
# 0    AK  3.230464e+07  3.160893e+07    2.216190
# 1    AL  1.570339e+07  1.477973e+07    6.503329
# 2    AR  1.376200e+07  1.298657e+07    6.529845
# 3    AZ  2.719522e+07  2.529217e+07    8.283342
# 4    CA  7.463291e+07  6.776819e+07    9.793955

# %%
fig = px.choropleth(map_df, locations='State', locationmode='USA-states',
                    color='2018-04-01', scope='usa', color_continuous_scale='Purples', 
            title='Percent Yearly Average ROI by State')
fig.show()
# Out:
# <div>
#
#
#             <div id="827ab0b2-5939-45b4-a4dc-44cb6671a279" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("827ab0b2-5939-45b4-a4dc-44cb6671a279")) {
#                     Plotly.newPlot(
#                         '827ab0b2-5939-45b4-a4dc-44cb6671a279',
#                         [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "State=%{location}<br>2018-04-01=%{z}<extra></extra>", "locationmode": "USA-states", "locations": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "name": "", "type": "choropleth", "z": [2.2161904372699137, 6.5033292323903975, 6.52984461789186, 8.283341827526261, 9.793954521967162, 8.55036350492543, 3.25507336594553, 5.508695886152637, 3.6286437525578856, 9.581948488313746, 7.4436249470814, 6.758920962320042, 3.1510982988706333, 7.9635108606665295, 3.5990857311700495, 7.800413624264986, 3.7808124487319357, 6.316542364168291, 3.1428313050106857, 6.917567044318197, 5.36984873536889, 7.478345620847962, 7.926254381693681, 6.408478619948483, 6.6031165514962185, 3.4888312984154646, 5.2431884920227985, 6.010393944562171, 1.5657284381308387, 8.545356604900046, 7.600755491378094, 8.406907962355598, 5.584711487428803, 14.208562391559967, 6.03600466363476, 6.847277750837629, 6.889086103205587, 8.744159452536836, 5.986972666456718, 8.889648960742925, 7.5736474758959265, 6.7669136846803255, 9.126966174403043, 6.548195565790607, 10.27149531653235, 4.046322347070922, 1.2532284259312434, 11.804520393432966, 6.04950072946542, 3.636559725243513, 3.791176420920608]}],
#                         {"coloraxis": {"colorbar": {"title": {"text": "2018-04-01"}}, "colorscale": [[0.0, "rgb(252,251,253)"], [0.125, "rgb(239,237,245)"], [0.25, "rgb(218,218,235)"], [0.375, "rgb(188,189,220)"], [0.5, "rgb(158,154,200)"], [0.625, "rgb(128,125,186)"], [0.75, "rgb(106,81,163)"], [0.875, "rgb(84,39,143)"], [1.0, "rgb(63,0,125)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "scope": "usa"}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl" ...

# %%
map_df.to_csv('map_df.csv', index=False)

# %%
michigan = z_df.loc[z_df['State']=='MI']
michigan.head()
# Out:
#      RegionID  RegionName          City State      Metro CountyName  SizeRank  \
# 87      79054       48197     Ypsilanti    MI  Ann Arbor  Washtenaw        88
# 121     79040       48180        Taylor    MI    Detroit      Wayne       122
# 220     78975       48103     Ann Arbor    MI  Ann Arbor  Washtenaw       221
# 238     79044       48185      Westland    MI    Detroit      Wayne       239
# 313     79398       48823  East Lansing    MI    Lansing     Ingham       314
#
#       1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  \
# 87   129200.0  129800.0  130400.0  ...   200200   201700   202800   203500
# 121   69000.0   69500.0   69800.0  ...    87700    88500    88900    89200
# 220  150100.0  150800.0  151400.0  ...   339900   342800   345600   347800
# 238   94800.0   95500.0   96300.0  ...   132900   135000   136600   137400
# 313   74800.0   74700.0   74700.0  ...   189200   189700   190300   191900
#
#      2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 87    204300   205000   205700   207400   210300   212300
# 121    90300    91700    93000    94000    95100    96200
# 220   350300   352900   355700   360200   365900   369800
# 238   138200   139200   140100   140900   141700   142400
# 313   194900   196200   195200   194300   194400   194900
#
# [5 rows x 272 columns]

# %%
# filter zipcodes with a size rank in the top 1% (highly urbanized zipcodes)

urban = michigan.SizeRank.quantile(q=0.01)
print(f'Size Rank 01% cutoff value: {urban}')
mi = michigan[michigan['SizeRank'] < urban]
print(f'Amount of zipcodes: {len(mi)}')
mi.head()
# Out:
# Size Rank 01% cutoff value: 506.0800000000001
# Amount of zipcodes: 5
#      RegionID  RegionName          City State      Metro CountyName  SizeRank  \
# 87      79054       48197     Ypsilanti    MI  Ann Arbor  Washtenaw        88
# 121     79040       48180        Taylor    MI    Detroit      Wayne       122
# 220     78975       48103     Ann Arbor    MI  Ann Arbor  Washtenaw       221
# 238     79044       48185      Westland    MI    Detroit      Wayne       239
# 313     79398       48823  East Lansing    MI    Lansing     Ingham       314
#
#       1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  \
# 87   129200.0  129800.0  130400.0  ...   200200   201700   202800   203500
# 121   69000.0   69500.0   69800.0  ...    87700    88500    88900    89200
# 220  150100.0  150800.0  151400.0  ...   339900   342800   345600   347800
# 238   94800.0   95500.0   96300.0  ...   132900   135000   136600   137400
# 313   74800.0   74700.0   74700.0  ...   189200   189700   190300   191900
#
#      2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 87    204300   205000   205700   207400   210300   212300
# 121    90300    91700    93000    94000    95100    96200
# 220   350300   352900   355700   360200   365900   369800
# 238   138200   139200   140100   140900   141700   142400
# 313   194900   196200   195200   194300   194400   194900
#
# [5 rows x 272 columns]

# %%
mich_df = pd.DataFrame()
mich_df['SizeRank'] = mi['SizeRank']
mich_df['ZipCodes'] = mi['RegionName']
mich_df
# Out:
#      SizeRank  ZipCodes
# 87         88     48197
# 121       122     48180
# 220       221     48103
# 238       239     48185
# 313       314     48823

# %%
cate_df = pd.DataFrame()
cate_df['SizeRank'] = chicago['SizeRank']

# %%
cate_df['ZipCodes'] = chicago['RegionName']

# %%
cate_df.index
# Out:
# Int64Index([0, 3, 7, 16, 19, 40, 48, 50], dtype='int64')

# %%
cate_df['Risk'] = ['Moderate', 'Low', 'High', 'Moderate', 'Low', 'Low', 'High', 'Low']

# %%
cate_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8 entries, 0 to 50
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SizeRank  8 non-null      int64
#  1   ZipCodes  8 non-null      int64
# dtypes: int64(2)
# memory usage: 192.0 bytes

# %%
cate_df.head()
# Out:
#     SizeRank  ZipCodes      Risk TrainLines
# 0          1     60657  Moderate        Red
# 3          4     60614       Low       Blue
# 7          8     60640      High      Brown
# 16        17     60647  Moderate       Pink
# 19        20     60618       Low        Red

# %%
cate_df['TrainLines'] = ['Red', 'Blue', 'Brown', 'Pink', 'Red', 'Blue', 'Red', 'Brown']

# %%
cate_df['Neighborhood'] = ['Lincoln Square', 'Uptown', 'Uptown', 'Boystown', 'Uptown', 
                           'Chicago Lawn', 'Logan Square', 'Boystown']

# %%
import plotly.graph_objects as go

df = cate_df
fig = px.parallel_categories(df)

# df = px.data.tips()
# fig = px.parallel_categories(df, dimensions=['sex', 'smoker', 'day'],
#                 color="size", color_continuous_scale=px.colors.sequential.Inferno,
#                 labels={'sex':'Payer sex', 'smoker':'Smokers at the table', 'day':'Day of week'})

fig.show()
# Out:
# <div>
#
#
#             <div id="0196f74e-376a-458d-87f7-e4f165f1b23c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0196f74e-376a-458d-87f7-e4f165f1b23c")) {
#                     Plotly.newPlot(
#                         '0196f74e-376a-458d-87f7-e4f165f1b23c',
#                         [{"dimensions": [{"label": "SizeRank", "values": [1, 4, 8, 17, 20, 41, 49, 51]}, {"label": "ZipCodes", "values": [60657, 60614, 60640, 60647, 60618, 60613, 60629, 60625]}, {"label": "Risk", "values": ["Moderate", "Low", "High", "Moderate", "Low", "Low", "High", "Low"]}, {"label": "TrainLines", "values": ["Red", "Blue", "Brown", "Pink", "Red", "Blue", "Red", "Brown"]}, {"label": "Neighborhood", "values": ["Lincoln Square", "Uptown", "Uptown", "Boystown", "Uptown", "Chicago Lawn", "Logan Square", "Boystown"]}], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "name": "", "type": "parcats"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import statsmodels.api as sm
import itertools

# plt.style.use('fivethirtyeight')
# %matplotlib inline
# from matplotlib.pylab import rcParams
# rcParams['figure.figsize'] = 13, 8

import plotly.express as px

# import collections

import functions as fun



import datetime
import seaborn as sns
sns.set()

# %%
# %load_ext autoreload
# %autoreload

# %%
# %reload_ext autoreload

# %% [markdown]
# # Step 1: Read in Data

# %%
z_df = pd.read_csv('zillow_data.csv')
z_df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
z_df.shape
# Out:
# (14723, 272)

# %% [markdown]
# The data contains the following values:
#
# - RegionId - regions id (useful for mapping with fips?)
# - RegionName - the zip code of the row
# - City - city corresponding to the zip code
# - State - state the zip code
# - Metro - if applicable - the metro area corresponding to the city/zip code
# - CountyName - county that the zip code belongs to
# - SizeRank - this is based on population density (people per square mile) of the zip code -->
#     - lower scores = higher population density/more urbanized
#     - higher scores = lower population density/less urbanized
# - dates/home value - monthly home values from April, 1996 - April, 2018
#
# It is important to have a good understanding of the data.
# We will therefore explore the various features.

# %% [markdown]
# ### I started with a function for checking the total and percentages of missing values of each column.

# %%
missing = fun.missing_data(z_df)
missing
# Out:
#          Total   Percent
# Metro     1043  7.084154
# 1997-03   1039  7.056986
# 1996-07   1039  7.056986
# 1997-06   1039  7.056986
# 1997-02   1039  7.056986
# ...        ...       ...
# 2014-05     56  0.380357
# 2014-04     56  0.380357
# 2014-02     56  0.380357
# 2014-01     56  0.380357
# 2014-03     56  0.380357
#
# [220 rows x 2 columns]

# %% [markdown]
# #### There are random missing values spread through a lot of the months
# - until we explore further this is not helpful yet
# - until we scale to a specific location this is not helpful yet

# %% [markdown]
# ### Chicago -->  I decided to only focus on Chicago zip codes because there are over 14,000 zip codes.
# I believe that this is a great area for investment because:
# - it is a large city with many zip codes
# - it is highly urbanized and has potential for large growth / is constantly growing in population
# - walkability scores
# - restaurants within walking distance
# - possibility of looking into zip codes closest to public transportation
# - low carbon emissions because of high population and urbanization

# %% [markdown]
# # Step 2: Data Preprocessing and Step 3: EDA and Visualization

# %%
# get only zip codes in Chicago
df_chicago = z_df.loc[z_df['City']=='Chicago']
df_chicago.head()
# Out:
#     RegionID  RegionName     City State    Metro CountyName  SizeRank  \
# 0      84654       60657  Chicago    IL  Chicago       Cook         1
# 3      84616       60614  Chicago    IL  Chicago       Cook         4
# 7      84640       60640  Chicago    IL  Chicago       Cook         8
# 16     84646       60647  Chicago    IL  Chicago       Cook        17
# 19     84620       60618  Chicago    IL  Chicago       Cook        20
#
#      1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  \
# 0   334200.0  335400.0  336500.0  ...  1005500  1007500  1007800  1009600
# 3   498100.0  500900.0  503100.0  ...  1289800  1287700  1287400  1291500
# 7   216500.0  216700.0  216900.0  ...   798000   787100   776100   774900
# 16  122700.0  122800.0  122800.0  ...   459600   461400   464300   466500
# 19  142600.0  143100.0  143400.0  ...   462700   461200   459900   459200
#
#     2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1013300  1018700  1024400  1030700  1033800  1030600
# 3   1296600  1299000  1302700  1306400  1308500  1307000
# 7    777900   777900   778500   780500   782800   782800
# 16   467900   470600   474500   475100   472600   470200
# 19   458700   457900   457400   459000   462500   464300
#
# [5 rows x 272 columns]

# %%
# Let's make a back up to be safe from overriding
df_chicago_copy = df_chicago.copy()
# df_chicago_copy

# %%
chi_missing = fun.missing_data(df_chicago)
chi_missing
# Out:
#          Total   Percent
# 2006-12      1  2.439024
# 2007-02      1  2.439024
# 2000-06      1  2.439024
# 2006-11      1  2.439024
# 2006-10      1  2.439024
# ...        ...       ...
# 2012-01      1  2.439024
# 2012-02      1  2.439024
# 2012-03      1  2.439024
# 2012-04      1  2.439024
# 2000-08      1  2.439024
#
# [207 rows x 2 columns]

# %%
chi_missing.Total.nunique()
# Out:
# 1

# %% [markdown]
# #### Looks like possibly only one row has null values.

# %%
missing_val = df_chicago.isnull()
null_row = missing_val.any(axis=1)
rows_with_missing = df_chicago[null_row]
rows_with_missing
# Out:
#      RegionID  RegionName     City State    Metro CountyName  SizeRank  \
# 105     84613       60611  Chicago    IL  Chicago       Cook       106
#
#      1996-04  1996-05  1996-06  ...  2017-07  2017-08  2017-09  2017-10  \
# 105      NaN      NaN      NaN  ...  1475200  1473900  1469500  1472100
#
#      2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 105  1477800  1486000  1497300  1508600  1508100  1493200
#
# [1 rows x 272 columns]

# %% [markdown]
# #### Discovered that the zip code 60611 is our row with missing data.
# - It looks like there are months with missing data for this zip code - possibly didn't have early on data?

# %% [markdown]
# #### Change name of RegionName column to ZipCode to elimate confusion with RegionID column

# %%
df_chicago.rename(columns={'RegionName': 'ZipCode'}, inplace=True)
df_chicago.head()
# Out:
#     RegionID  ZipCode     City State    Metro CountyName  SizeRank   1996-04  \
# 0      84654    60657  Chicago    IL  Chicago       Cook         1  334200.0
# 3      84616    60614  Chicago    IL  Chicago       Cook         4  498100.0
# 7      84640    60640  Chicago    IL  Chicago       Cook         8  216500.0
# 16     84646    60647  Chicago    IL  Chicago       Cook        17  122700.0
# 19     84620    60618  Chicago    IL  Chicago       Cook        20  142600.0
#
#      1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 0   335400.0  336500.0  ...  1005500  1007500  1007800  1009600  1013300
# 3   500900.0  503100.0  ...  1289800  1287700  1287400  1291500  1296600
# 7   216700.0  216900.0  ...   798000   787100   776100   774900   777900
# 16  122800.0  122800.0  ...   459600   461400   464300   466500   467900
# 19  143100.0  143400.0  ...   462700   461200   459900   459200   458700
#
#     2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1018700  1024400  1030700  1033800  1030600
# 3   1299000  1302700  1306400  1308500  1307000
# 7    777900   778500   780500   782800   782800
# 16   470600   474500   475100   472600   470200
# 19   457900   457400   459000   462500   464300
#
# [5 rows x 272 columns]

# %%
# make sure all zip codes are Cook County 
df_chicago['CountyName'].nunique()
# Out:
# 1

# %%
df_chicago['ZipCode'].nunique()
# Out:
# 41

# %%
df_chicago.shape
# Out:
# (41, 272)

# %% [markdown]
# ### Now we have 41 zip codes to forecast with.

# %%
plt.figure(figsize=(13,8))
sns.barplot(x='ZipCode', y='2018-01', data=df_chicago, palette="rocket_r")
plt.title('Home Values by Zip Code in January, 2018')
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.barplot(x='ZipCode', y='2011-01', data=df_chicago, palette="rocket_r")
plt.title('Home Values by Zip Code in January, 2011')
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.barplot(x='ZipCode', y='SizeRank', data=df_chicago, palette="rocket_r")
plt.title('Size Rank of Chicago Zip Codes')
plt.xticks(rotation=60)
plt.show()

# %% [markdown]
# #### From here I decided to use size rank to filter through and lessen the zip code amount.
# - I did not have a set amount of zip codes in mind
# - Just play with different percentages

# %%
# I am dropping the column with no data until 2013 - I reference this below!!
df_chicago.dropna(inplace=True)
df_chicago['ZipCode'].nunique()
# Out:
# 40

# %%
# filter zipcodes with a size rank in the bottom 50% (low score = highly urbanized zipcodes)
urban = df_chicago.SizeRank.quantile(q=0.50)
print(f'Size Rank 50% cutoff value: {urban}')
top_zips_df = df_chicago[df_chicago['SizeRank'] < urban]
print(f'Amount of zip codes: {top_zips_df.ZipCode.nunique()}')
top_zips_df.head()
# Out:
# Size Rank 50% cutoff value: 568.5
# Amount of zip codes: 20
#     RegionID  ZipCode     City State    Metro CountyName  SizeRank   1996-04  \
# 0      84654    60657  Chicago    IL  Chicago       Cook         1  334200.0
# 3      84616    60614  Chicago    IL  Chicago       Cook         4  498100.0
# 7      84640    60640  Chicago    IL  Chicago       Cook         8  216500.0
# 16     84646    60647  Chicago    IL  Chicago       Cook        17  122700.0
# 19     84620    60618  Chicago    IL  Chicago       Cook        20  142600.0
#
#      1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 0   335400.0  336500.0  ...  1005500  1007500  1007800  1009600  1013300
# 3   500900.0  503100.0  ...  1289800  1287700  1287400  1291500  1296600
# 7   216700.0  216900.0  ...   798000   787100   776100   774900   777900
# 16  122800.0  122800.0  ...   459600   461400   464300   466500   467900
# 19  143100.0  143400.0  ...   462700   461200   459900   459200   458700
#
#     2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1018700  1024400  1030700  1033800  1030600
# 3   1299000  1302700  1306400  1308500  1307000
# 7    777900   778500   780500   782800   782800
# 16   470600   474500   475100   472600   470200
# 19   457900   457400   459000   462500   464300
#
# [5 rows x 272 columns]

# %%
top_zips_df.to_csv('top_zips_with_all_columns.csv', index=False)

# %%
## go back and make sure mapping dictionary is updated!!

# %%
# making a dictionary of zip codes with their corresponding region id's 
# because I may need them for plotting or identification of zip code location
# region
region_dict = {}
zip_list = top_zips_df.ZipCode.unique()
for i in zip_list:
    region = top_zips_df[top_zips_df['ZipCode']==i].RegionID.values[0]
    region_dict[i] = region

# %%
region_dict[60657]
# Out:
# 84654

# %%
plt.figure(figsize=(13,8))
sns.barplot(x='ZipCode', y='SizeRank', data=top_zips_df, palette="rocket_r")
plt.title('Size Rank of Highest Urbanized Chicago Zip Codes')
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.barplot(x='ZipCode', y='2018-01', data=top_zips_df, palette="rocket_r")
plt.title('Home Values of Highest Urbanized Zip Codes in January, 2018')
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.barplot(x='ZipCode', y='2011-01', data=top_zips_df, palette="rocket_r")
plt.title('Home Values of Highest Urbanized Zip Codes in January, 2011')
plt.xticks(rotation=60)
plt.show()

# %%
plt.figure(figsize=(13,8))
sns.barplot(x='ZipCode', y='1997-01', data=top_zips_df, palette="rocket_r")
# sns.catplot(x='ZipCode', y='1997-01',  data=top_zips_df, palette= 'rocket_r')
plt.title('Home Values of Highest Urbanized Zip Codes in January, 1997')
plt.xticks(rotation=60)
plt.show()

# %%
newfig = plt.figure(figsize = (13, 8))
ax = newfig.add_subplot(121)
ax2 = newfig.add_subplot(122)
ax.set_title('')
ax2.set_title('')
sns.barplot(x='ZipCode', y='1997-01', data=top_zips_df, palette="rocket_r",ax=ax,  )
sns.barplot(x='ZipCode', y='1999-01', data=top_zips_df, palette="rocket_r", ax=ax2)
# plt.setp(ax, xticks = [])
plt.setp(ax.get_xticklabels(), rotation=55)
plt.setp(ax2.get_xticklabels(), rotation=55)
# plt.xticks(rotation=50)
plt.close(2)
plt.close(3)

# %%
newfig = plt.figure(figsize = (13, 8))
ax = newfig.add_subplot(121)
ax2 = newfig.add_subplot(122)
ax.set_title('')
ax2.set_title('')
sns.barplot(x='ZipCode', y='2014-01', data=top_zips_df, palette="rocket_r",ax=ax,  )
sns.barplot(x='ZipCode', y='2018-01', data=top_zips_df, palette="rocket_r", ax=ax2)
# plt.setp(ax, xticks = [])
plt.setp(ax.get_xticklabels(), rotation=55)
plt.setp(ax2.get_xticklabels(), rotation=55)
# plt.xticks(rotation=50)
plt.close(2)
plt.close(3)

# %%
top_zips_df.head()
# Out:
#     RegionID  ZipCode     City State    Metro CountyName  SizeRank   1996-04  \
# 0      84654    60657  Chicago    IL  Chicago       Cook         1  334200.0
# 3      84616    60614  Chicago    IL  Chicago       Cook         4  498100.0
# 7      84640    60640  Chicago    IL  Chicago       Cook         8  216500.0
# 16     84646    60647  Chicago    IL  Chicago       Cook        17  122700.0
# 19     84620    60618  Chicago    IL  Chicago       Cook        20  142600.0
#
#      1996-05   1996-06  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 0   335400.0  336500.0  ...  1005500  1007500  1007800  1009600  1013300
# 3   500900.0  503100.0  ...  1289800  1287700  1287400  1291500  1296600
# 7   216700.0  216900.0  ...   798000   787100   776100   774900   777900
# 16  122800.0  122800.0  ...   459600   461400   464300   466500   467900
# 19  143100.0  143400.0  ...   462700   461200   459900   459200   458700
#
#     2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1018700  1024400  1030700  1033800  1030600
# 3   1299000  1302700  1306400  1308500  1307000
# 7    777900   778500   780500   782800   782800
# 16   470600   474500   475100   472600   470200
# 19   457900   457400   459000   462500   464300
#
# [5 rows x 272 columns]

# %% [markdown]
# ### I wanted to drop some unnecessary columns to plot each zip code's value change over time.

# %%
plotting_df = top_zips_df.drop(['RegionID', 'City', 'State', 'Metro', 'CountyName', 'SizeRank'], axis=1)
plotting_df.head()
# Out:
#     ZipCode   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0     60657  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 3     60614  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 7     60640  216500.0  216700.0  216900.0  217000.0  217100.0  217200.0
# 16    60647  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0
# 19    60618  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0
#
#      1996-10   1996-11   1996-12  ...  2017-07  2017-08  2017-09  2017-10  \
# 0   340400.0  341300.0  342600.0  ...  1005500  1007500  1007800  1009600
# 3   505300.0  504200.0  503600.0  ...  1289800  1287700  1287400  1291500
# 7   217500.0  217900.0  218600.0  ...   798000   787100   776100   774900
# 16  121500.0  120900.0  120500.0  ...   459600   461400   464300   466500
# 19  141300.0  140100.0  139000.0  ...   462700   461200   459900   459200
#
#     2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1013300  1018700  1024400  1030700  1033800  1030600
# 3   1296600  1299000  1302700  1306400  1308500  1307000
# 7    777900   777900   778500   780500   782800   782800
# 16   467900   470600   474500   475100   472600   470200
# 19   458700   457900   457400   459000   462500   464300
#
# [5 rows x 266 columns]

# %%
## Reset index 
plot_df = plotting_df.reset_index(drop=True)
plot_df.head()
# Out:
#    ZipCode   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0    60657  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 1    60614  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 2    60640  216500.0  216700.0  216900.0  217000.0  217100.0  217200.0
# 3    60647  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0
# 4    60618  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0
#
#     1996-10   1996-11   1996-12  ...  2017-07  2017-08  2017-09  2017-10  \
# 0  340400.0  341300.0  342600.0  ...  1005500  1007500  1007800  1009600
# 1  505300.0  504200.0  503600.0  ...  1289800  1287700  1287400  1291500
# 2  217500.0  217900.0  218600.0  ...   798000   787100   776100   774900
# 3  121500.0  120900.0  120500.0  ...   459600   461400   464300   466500
# 4  141300.0  140100.0  139000.0  ...   462700   461200   459900   459200
#
#    2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1013300  1018700  1024400  1030700  1033800  1030600
# 1  1296600  1299000  1302700  1306400  1308500  1307000
# 2   777900   777900   778500   780500   782800   782800
# 3   467900   470600   474500   475100   472600   470200
# 4   458700   457900   457400   459000   462500   464300
#
# [5 rows x 266 columns]

# %%
## change zipcodes to string
plot_df["ZipCode"] = plot_df["ZipCode"].astype(str)

# %%
## transpose dates to rows
plot_df = plot_df.transpose()
plot_df.head()
# Out:
#               0       1       2       3       4       5      6       7      8  \
# ZipCode   60657   60614   60640   60647   60618   60613  60629   60625  60619
# 1996-04  334200  498100  216500  122700  142600  297900  93400  148900  76400
# 1996-05  335400  500900  216700  122800  143100  300400  94100  149300  77000
# 1996-06  336500  503100  216900  122800  143400  302600  94600  149600  77400
# 1996-07  337600  504600  217000  122700  143300  304700  94800  149700  77700
#
#               9     10      11      12     13      14      15      16      17  \
# ZipCode   60610  60620   60634   60626  60649   60616   60622   60615   60641
# 1996-04  435200  71900  146800  150900  77400  160600  217000  195300  135700
# 1996-05  435200  72500  147700  150100  77600  160400  216900  196600  136200
# 1996-06  435100  73000  148300  149300  77600  160100  216900  197800  136400
# 1996-07  434600  73300  148500  148400  77600  159800  216800  198900  136300
#
#              18     19
# ZipCode   60660  60608
# 1996-04  166000  89800
# 1996-05  165600  89800
# 1996-06  165200  89800
# 1996-07  164800  89700

# %%
## Renaming columns
header = plot_df.iloc[0] ## grab first row for the column names
plot_df = plot_df[1:] ## take all data after first row
plot_df.columns = header ## reassign all columns to zipcodes
plot_df.head()
# Out:
# ZipCode   60657   60614   60640   60647   60618   60613  60629   60625  60619  \
# 1996-04  334200  498100  216500  122700  142600  297900  93400  148900  76400
# 1996-05  335400  500900  216700  122800  143100  300400  94100  149300  77000
# 1996-06  336500  503100  216900  122800  143400  302600  94600  149600  77400
# 1996-07  337600  504600  217000  122700  143300  304700  94800  149700  77700
# 1996-08  338500  505500  217100  122400  142900  306600  94700  149700  77700
#
# ZipCode   60610  60620   60634   60626  60649   60616   60622   60615   60641  \
# 1996-04  435200  71900  146800  150900  77400  160600  217000  195300  135700
# 1996-05  435200  72500  147700  150100  77600  160400  216900  196600  136200
# 1996-06  435100  73000  148300  149300  77600  160100  216900  197800  136400
# 1996-07  434600  73300  148500  148400  77600  159800  216800  198900  136300
# 1996-08  433900  73400  148400  147600  77500  159500  216800  199900  135800
#
# ZipCode   60660  60608
# 1996-04  166000  89800
# 1996-05  165600  89800
# 1996-06  165200  89800
# 1996-07  164800  89700
# 1996-08  164400  89500

# %%
# fun.plot(plot_df)
plot_df.plot(figsize=(13, 8))
plt.title('Most Urbanized Zip Codes across 1996-2018 by Home Value')
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", ncol=2)
plt.xlabel('Dates')
plt.ylabel('Home Value')
plt.show()

# %% [markdown]
# ### From the plot above - It is clear that the 2008 economic crash had a large impact on values in Chicago
# - I decided to discard of all dates prior to 2011 where it starts to even out

# %%
plot_df = plot_df.loc[plot_df.index >= '2011-01']
plot_df.head()
# Out:
# ZipCode   60657   60614   60640   60647   60618   60613   60629   60625  \
# 2011-01  729300  923000  600000  286500  317400  722000  125300  337500
# 2011-02  730200  925000  601600  285800  316300  723400  124300  339500
# 2011-03  730700  923300  599700  283800  314000  724200  123100  340600
# 2011-04  730000  916600  590500  282100  311400  722300  121500  340500
# 2011-05  730100  912400  578900  281700  308200  724100  119800  339500
#
# ZipCode   60619   60610   60620   60634   60626   60649   60616   60622  \
# 2011-01  122200  749200  127600  196600  316500  148800  289000  532700
# 2011-02  122200  748600  126900  195000  317900  148700  288100  531700
# 2011-03  122500  747300  125500  193200  319600  147200  287300  530900
# 2011-04  123300  745300  124600  190600  321400  144800  286400  530600
# 2011-05  123500  744200  123400  187600  320300  143200  286200  528700
#
# ZipCode   60615   60641   60660   60608
# 2011-01  372500  195100  429900  179800
# 2011-02  370600  194600  428800  179400
# 2011-03  368800  193700  426200  178200
# 2011-04  368900  191200  419400  176900
# 2011-05  369900  187600  413200  176800

# %%
# # fun.plot(plot_df)
plot_df.plot(figsize=(13, 8))
plt.title('Most Urbanized Zip Codes across 2011-2018 by Home Value')
plt.legend(bbox_to_anchor=(1.04,1), loc="upper left", ncol=2)
plt.xlabel('Dates')
plt.ylabel('Home Value')
plt.show()

# %%
plot_df.head()
# Out:
# ZipCode   60657   60614   60640   60647   60618   60613   60629   60625  \
# 2011-01  729300  923000  600000  286500  317400  722000  125300  337500
# 2011-02  730200  925000  601600  285800  316300  723400  124300  339500
# 2011-03  730700  923300  599700  283800  314000  724200  123100  340600
# 2011-04  730000  916600  590500  282100  311400  722300  121500  340500
# 2011-05  730100  912400  578900  281700  308200  724100  119800  339500
#
# ZipCode   60619   60610   60620   60634   60626   60649   60616   60622  \
# 2011-01  122200  749200  127600  196600  316500  148800  289000  532700
# 2011-02  122200  748600  126900  195000  317900  148700  288100  531700
# 2011-03  122500  747300  125500  193200  319600  147200  287300  530900
# 2011-04  123300  745300  124600  190600  321400  144800  286400  530600
# 2011-05  123500  744200  123400  187600  320300  143200  286200  528700
#
# ZipCode   60615   60641   60660   60608
# 2011-01  372500  195100  429900  179800
# 2011-02  370600  194600  428800  179400
# 2011-03  368800  193700  426200  178200
# 2011-04  368900  191200  419400  176900
# 2011-05  369900  187600  413200  176800

# %% [markdown]
# ### OK!  Looks good - these are the zip codes and years we will model with.

# %%
# save our filtered dataframe for future use and to prevent overriding
# NO INDEX with function ran !!
fun.get_index_ready(plot_df)

plot_df.to_csv('plot_df.csv', index=False)

# %% [markdown]
# # Step 4: Reshape from Wide to Long Format

# %%
top_zips_df.head()
# Out:
#     RegionID  ZipCode     City State    Metro CountyName  SizeRank   2011-01  \
# 0      84654    60657  Chicago    IL  Chicago       Cook         1  729300.0
# 3      84616    60614  Chicago    IL  Chicago       Cook         4  923000.0
# 7      84640    60640  Chicago    IL  Chicago       Cook         8  600000.0
# 16     84646    60647  Chicago    IL  Chicago       Cook        17  286500.0
# 19     84620    60618  Chicago    IL  Chicago       Cook        20  317400.0
#
#      2011-02   2011-03  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 0   730200.0  730700.0  ...  1005500  1007500  1007800  1009600  1013300
# 3   925000.0  923300.0  ...  1289800  1287700  1287400  1291500  1296600
# 7   601600.0  599700.0  ...   798000   787100   776100   774900   777900
# 16  285800.0  283800.0  ...   459600   461400   464300   466500   467900
# 19  316300.0  314000.0  ...   462700   461200   459900   459200   458700
#
#     2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1018700  1024400  1030700  1033800  1030600
# 3   1299000  1302700  1306400  1308500  1307000
# 7    777900   778500   780500   782800   782800
# 16   470600   474500   475100   472600   470200
# 19   457900   457400   459000   462500   464300
#
# [5 rows x 95 columns]

# %%
for col in top_zips_df.columns:
    if col < '2011-01':
        top_zips_df.drop([col], inplace=True, axis=1)

top_zips_df.head()
# Out:
#     RegionID  ZipCode     City State    Metro CountyName  SizeRank   2011-01  \
# 0      84654    60657  Chicago    IL  Chicago       Cook         1  729300.0
# 3      84616    60614  Chicago    IL  Chicago       Cook         4  923000.0
# 7      84640    60640  Chicago    IL  Chicago       Cook         8  600000.0
# 16     84646    60647  Chicago    IL  Chicago       Cook        17  286500.0
# 19     84620    60618  Chicago    IL  Chicago       Cook        20  317400.0
#
#      2011-02   2011-03  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 0   730200.0  730700.0  ...  1005500  1007500  1007800  1009600  1013300
# 3   925000.0  923300.0  ...  1289800  1287700  1287400  1291500  1296600
# 7   601600.0  599700.0  ...   798000   787100   776100   774900   777900
# 16  285800.0  283800.0  ...   459600   461400   464300   466500   467900
# 19  316300.0  314000.0  ...   462700   461200   459900   459200   458700
#
#     2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1018700  1024400  1030700  1033800  1030600
# 3   1299000  1302700  1306400  1308500  1307000
# 7    777900   778500   780500   782800   782800
# 16   470600   474500   475100   472600   470200
# 19   457900   457400   459000   462500   464300
#
# [5 rows x 95 columns]

# %%
def melt_data(df): # from flatiron starter notebook
    melted = pd.melt(df, id_vars=['RegionID','ZipCode', 'City', 'State', 'Metro', 'CountyName','SizeRank'], var_name='Time', value_name='Value')
    melted['Time'] = pd.to_datetime(melted['Time'], format='%Y-%m')
    melted = melted.dropna(subset=['Value'])
    return melted

# %%
df = melt_data(top_zips_df)
df.head()
# Out:
#    RegionID  ZipCode     City State    Metro CountyName  SizeRank       Time  \
# 0     84654    60657  Chicago    IL  Chicago       Cook         1 2011-01-01
# 1     84616    60614  Chicago    IL  Chicago       Cook         4 2011-01-01
# 2     84640    60640  Chicago    IL  Chicago       Cook         8 2011-01-01
# 3     84646    60647  Chicago    IL  Chicago       Cook        17 2011-01-01
# 4     84620    60618  Chicago    IL  Chicago       Cook        20 2011-01-01
#
#       Value
# 0  729300.0
# 1  923000.0
# 2  600000.0
# 3  286500.0
# 4  317400.0

# %%
df.drop(['RegionID', 'City', 'State', 'Metro', 
                     'CountyName', 'SizeRank'], inplace=True, axis=1)
# df.head()

# %%
df.head()
# Out:
#    ZipCode       Time     Value
# 0    60657 2011-01-01  729300.0
# 1    60614 2011-01-01  923000.0
# 2    60640 2011-01-01  600000.0
# 3    60647 2011-01-01  286500.0
# 4    60618 2011-01-01  317400.0

# %%
# no index
# df.to_csv('chicago_melted.csv', index=False)

# %%
# df.set_index('Time', inplace = True)
# df.head()

# %%
y = pd.DataFrame(df.groupby('Time')['Value'].mean())
y.head()
# Out:
#                Value
# Time
# 2011-01-01  385045.0
# 2011-02-01  384930.0
# 2011-03-01  383990.0
# 2011-04-01  381915.0
# 2011-05-01  379965.0

# %%
# all of chicago with mean values - no zip
y.plot(figsize=(13, 8))
plt.xlabel("Year", fontsize=16)
plt.ylabel("Home Value", fontsize=16)
plt.title("Mean Home Value for Top Urbanized Chicago Zipcodes", fontsize=20)
plt.show()

# %% [markdown]
# # ROI Evaluations:

# %%
plotting_df.head()
# Out:
#     ZipCode   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0     60657  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 3     60614  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 7     60640  216500.0  216700.0  216900.0  217000.0  217100.0  217200.0
# 16    60647  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0
# 19    60618  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0
#
#      1996-10   1996-11   1996-12  ...  2017-07  2017-08  2017-09  2017-10  \
# 0   340400.0  341300.0  342600.0  ...  1005500  1007500  1007800  1009600
# 3   505300.0  504200.0  503600.0  ...  1289800  1287700  1287400  1291500
# 7   217500.0  217900.0  218600.0  ...   798000   787100   776100   774900
# 16  121500.0  120900.0  120500.0  ...   459600   461400   464300   466500
# 19  141300.0  140100.0  139000.0  ...   462700   461200   459900   459200
#
#     2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1013300  1018700  1024400  1030700  1033800  1030600
# 3   1296600  1299000  1302700  1306400  1308500  1307000
# 7    777900   777900   778500   780500   782800   782800
# 16   467900   470600   474500   475100   472600   470200
# 19   458700   457900   457400   459000   462500   464300
#
# [5 rows x 266 columns]

# %%
roi_df = plotting_df.copy()
roi_df.head()
# Out:
#     ZipCode   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0     60657  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 3     60614  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 7     60640  216500.0  216700.0  216900.0  217000.0  217100.0  217200.0
# 16    60647  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0
# 19    60618  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0
#
#      1996-10   1996-11   1996-12  ...  2017-07  2017-08  2017-09  2017-10  \
# 0   340400.0  341300.0  342600.0  ...  1005500  1007500  1007800  1009600
# 3   505300.0  504200.0  503600.0  ...  1289800  1287700  1287400  1291500
# 7   217500.0  217900.0  218600.0  ...   798000   787100   776100   774900
# 16  121500.0  120900.0  120500.0  ...   459600   461400   464300   466500
# 19  141300.0  140100.0  139000.0  ...   462700   461200   459900   459200
#
#     2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0   1013300  1018700  1024400  1030700  1033800  1030600
# 3   1296600  1299000  1302700  1306400  1308500  1307000
# 7    777900   777900   778500   780500   782800   782800
# 16   467900   470600   474500   475100   472600   470200
# 19   458700   457900   457400   459000   462500   464300
#
# [5 rows x 266 columns]

# %% [markdown]
# ### I want to first take the average of every year so as not to lose any valuable information.

# %%
year_list = ['1996', '1997','1998', '1999','2000', '2001','2002',
             '2003','2004','2005','2006','2007','2008','2009',
             '2010','2011', '2012', '2013', '2014', '2015', 
             '2016', '2017', '2018']

# %%
# %reload_ext autoreload

# %%
for year in year_list:
    fun.get_mean_year(roi_df, year)

# %%
roi_df.head()
# Out:
#     ZipCode   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 0     60657  334200.0  335400.0  336500.0  337600.0  338500.0  339500.0
# 3     60614  498100.0  500900.0  503100.0  504600.0  505500.0  505700.0
# 7     60640  216500.0  216700.0  216900.0  217000.0  217100.0  217200.0
# 16    60647  122700.0  122800.0  122800.0  122700.0  122400.0  122000.0
# 19    60618  142600.0  143100.0  143400.0  143300.0  142900.0  142200.0
#
#      1996-10   1996-11   1996-12  ...     2009    2010    2011    2012  \
# 0   340400.0  341300.0  342600.0  ...   790743  760244  732548  761040
# 3   505300.0  504200.0  503600.0  ...  1014667  964985  920240  965996
# 7   217500.0  217900.0  218600.0  ...   654189  612099  582324  552544
# 16  121500.0  120900.0  120500.0  ...   326094  295397  283307  282759
# 19  141300.0  140100.0  139000.0  ...   349025  325650  305273  304986
#
#        2013     2014     2015     2016     2017     2018
# 0    834854   881141   918897   975076  1001805  1028402
# 3   1078377  1163246  1196334  1246987  1286311  1304973
# 7    576204   620609   687837   736271   776390   780645
# 16   321985   335174   369550   429273   457312   472169
# 19   346769   371575   381782   433078   461936   460633
#
# [5 rows x 289 columns]

# %% [markdown]
# ### Toss all individual months since I now have the average home value for each year

# %%
for col in roi_df:
    if '-' in col:
        roi_df.drop([col], inplace=True, axis=1)
roi_df.head()
# Out:
#     ZipCode    1996    1997    1998    1999    2000    2001    2002    2003  \
# 0     60657  345921  352942  396505  466646  565227  653381  711351  744140
# 3     60614  512123  499496  561259  651321  750713  853123  931631  993753
# 7     60640  223373  227483  260710  313352  379441  439705  488811  525081
# 16    60647  125795  119906  133649  153535  184238  222121  246892  275076
# 19    60618  145467  133178  150818  175660  213341  256170  274249  298255
#
#        2004  ...     2009    2010    2011    2012     2013     2014     2015  \
# 0    783799  ...   790743  760244  732548  761040   834854   881141   918897
# 3   1039340  ...  1014667  964985  920240  965996  1078377  1163246  1196334
# 7    559548  ...   654189  612099  582324  552544   576204   620609   687837
# 16   305892  ...   326094  295397  283307  282759   321985   335174   369550
# 19   340297  ...   349025  325650  305273  304986   346769   371575   381782
#
#        2016     2017     2018
# 0    975076  1001805  1028402
# 3   1246987  1286311  1304973
# 7    736271   776390   780645
# 16   429273   457312   472169
# 19   433078   461936   460633
#
# [5 rows x 24 columns]

# %%
# flipping it for our plot function
plot_roi = roi_df.transpose()

new_header = plot_roi.iloc[0] 
plot_roi = plot_roi[1:] 
plot_roi.columns = new_header

# %% [markdown]
# ### Below is full range of dates - I just wanted to confirm that the 2008 economic crash looked the same with the averages for the years and it does.

# %%
# average value for each year 
fun.plot(plot_roi)

# %% [markdown]
# #### again eliminating all years before 2011 to account for 2008 crash

# %%
roi_clean = roi_df.copy()

for col in roi_df.columns:
    if col < '2011':
        roi_df.drop([col], inplace=True, axis=1)

roi_df.head()
# Out:
#     ZipCode    2011    2012     2013     2014     2015     2016     2017  \
# 0     60657  732548  761040   834854   881141   918897   975076  1001805
# 3     60614  920240  965996  1078377  1163246  1196334  1246987  1286311
# 7     60640  582324  552544   576204   620609   687837   736271   776390
# 16    60647  283307  282759   321985   335174   369550   429273   457312
# 19    60618  305273  304986   346769   371575   381782   433078   461936
#
#        2018
# 0   1028402
# 3   1304973
# 7    780645
# 16   472169
# 19   460633

# %%
roi_df['2012-01'] = fun.get_return_rate('2011', '2012', roi_df)
roi_df['2013-01'] = fun.get_return_rate('2012', '2013', roi_df)
roi_df['2014-01'] = fun.get_return_rate('2013', '2014', roi_df) 
roi_df['2015-01'] = fun.get_return_rate('2014', '2015', roi_df)
roi_df['2016-01'] = fun.get_return_rate('2015', '2016', roi_df) 
roi_df['2017-01'] = fun.get_return_rate('2016', '2017', roi_df) 
roi_df['2018-01'] = fun.get_return_rate('2017', '2018', roi_df) 
roi_df.drop(['2011', '2012', '2013', '2014', '2015', '2016', '2017',
       '2018'], inplace=True, axis=1)
roi_df.head()
# Out:
#     ZipCode   2012-01    2013-01   2014-01    2015-01    2016-01   2017-01  \
# 0     60657  3.889438   9.699096  5.544323   4.284899   6.113743  2.741222
# 3     60614  4.972181  11.633692  7.870068   2.844454   4.234018  3.153521
# 7     60640 -5.113992   4.282012  7.706472  10.832585   7.041494  5.448945
# 16    60647 -0.193430  13.872591  4.096154  10.256165  16.161007  6.531741
# 19    60618 -0.094014  13.699973  7.153465   2.746956  13.435940  6.663465
#
#      2018-01
# 0   2.654908
# 3   1.450816
# 7   0.548049
# 16  3.248767
# 19 -0.282074

# %%
mean_roi = roi_df.copy()

# %%
roi_df.columns
# Out:
# Index(['ZipCode', '2012-01', '2013-01', '2014-01', '2015-01', '2016-01',
#        '2017-01', '2018-01'],
#       dtype='object')

# %%
roi_df.ZipCode.nunique()
# Out:
# 20

# %%
date_roi = roi_df.groupby('ZipCode').mean()
date_roi.head()
# Out:
#           2012-01    2013-01   2014-01    2015-01    2016-01   2017-01  \
# ZipCode
# 60608   -2.341290  -2.285463  4.987373  12.844613  14.211499  4.908628
# 60610    4.072758  12.379611  4.776315   1.433900   4.370771  5.969273
# 60613    2.800758   6.726716  3.833597   6.477232   8.053622  5.611739
# 60614    4.972181  11.633692  7.870068   2.844454   4.234018  3.153521
# 60615   -0.811388   6.834005  5.682550   2.695844   5.904310  2.210173
#
#           2018-01
# ZipCode
# 60608   -1.051413
# 60610    0.894869
# 60613    4.230416
# 60614    1.450816
# 60615   -1.655522

# %%
zip_roi = date_roi.transpose()
zip_roi
# Out:
# ZipCode      60608      60610     60613      60614     60615      60616  \
# 2012-01  -2.341290   4.072758  2.800758   4.972181 -0.811388  -4.160558
# 2013-01  -2.285463  12.379611  6.726716  11.633692  6.834005  14.101278
# 2014-01   4.987373   4.776315  3.833597   7.870068  5.682550   3.233028
# 2015-01  12.844613   1.433900  6.477232   2.844454  2.695844  -1.537816
# 2016-01  14.211499   4.370771  8.053622   4.234018  5.904310   6.449733
# 2017-01   4.908628   5.969273  5.611739   3.153521  2.210173   3.825325
# 2018-01  -1.051413   0.894869  4.230416   1.450816 -1.655522  -0.016158
#
# ZipCode      60618      60619      60620      60622     60625      60626  \
# 2012-01  -0.094014  -8.022377 -15.460059  -0.464957 -3.789420  -3.967896
# 2013-01  13.699973  -4.457251   1.221693   6.504420  9.614868   7.976269
# 2014-01   7.153465   7.098000  -6.949125   8.019389  7.712691  10.070041
# 2015-01   2.746956   6.021584  13.437792   5.379275  1.326780   1.691988
# 2016-01  13.435940  -3.305035   9.975302  14.866787  6.512204   5.618084
# 2017-01   6.663465  11.312784   3.714702   5.969302  9.456422   4.794571
# 2018-01  -0.282074  -0.193671   3.078811   3.888344  2.328829  -2.203491
#
# ZipCode      60629      60634      60640      60641      60647      60649  \
# 2012-01  -7.329343  -7.259572  -5.113992  -4.601941  -0.193430  -4.296845
# 2013-01   7.589754  10.836620   4.282012  12.117835  13.872591  11.178277
# 2014-01   4.690640  14.589182   7.706472  14.268834   4.096154   2.855986
# 2015-01  10.669008   6.722084  10.832585   7.232349  10.256165  -0.022590
# 2016-01   8.872093   5.235217   7.041494   7.210999  16.161007 -15.246162
# 2017-01   6.221653   3.671752   5.448945   7.593036   6.531741  16.622233
# 2018-01   4.313305   3.772990   0.548049   3.871421   3.248767  -4.243521
#
# ZipCode     60657     60660
# 2012-01  3.889438 -3.564407
# 2013-01  9.699096  6.410396
# 2014-01  5.544323  6.198918
# 2015-01  4.284899  8.113196
# 2016-01  6.113743  9.106551
# 2017-01  2.741222 -1.326354
# 2018-01  2.654908  0.957737

# %%
zip_roi.plot(figsize=(13, 8))
plt.xlabel('Years', fontsize=16)
plt.ylabel('Percent ROI',  fontsize=16)
plt.legend(bbox_to_anchor=(1, 1), loc="upper left", ncol=2)
plt.title('Yearly ROI for Selected Highly Urbanized Chicago Zip Codes',  fontsize=20)
plt.show()

# %% [markdown]
# ### Let's filter out only the zip codes with an ROI percentage over 3% in 2018.

# %%
date_roi['2018-01'].unique()
# Out:
# array([-1.05141273,  0.89486883,  4.23041592,  1.45081555, -1.65552227,
#        -0.01615834, -0.28207371, -0.19367132,  3.07881082,  3.88834402,
#         2.32882897, -2.20349139,  4.31330499,  3.77299018,  0.54804931,
#         3.87142145,  3.24876671, -4.24352074,  2.65490789,  0.95773748])

# %%
# filter zipcodes ROI over 3% in 2018

top_percent = date_roi['2018-01'].quantile(q=0.75)
print(f'2018 ROI 75% cutoff value: {top_percent}')
top_roi = date_roi[date_roi['2018-01'] > top_percent]
print(f'Amount of zip codes: {top_roi.index.nunique()}')
top_roi.head()
# Out:
# 2018 ROI 75% cutoff value: 3.3798225750889515
# Amount of zip codes: 5
#           2012-01    2013-01    2014-01    2015-01    2016-01   2017-01  \
# ZipCode
# 60613    2.800758   6.726716   3.833597   6.477232   8.053622  5.611739
# 60622   -0.464957   6.504420   8.019389   5.379275  14.866787  5.969302
# 60629   -7.329343   7.589754   4.690640  10.669008   8.872093  6.221653
# 60634   -7.259572  10.836620  14.589182   6.722084   5.235217  3.671752
# 60641   -4.601941  12.117835  14.268834   7.232349   7.210999  7.593036
#
#           2018-01
# ZipCode
# 60613    4.230416
# 60622    3.888344
# 60629    4.313305
# 60634    3.772990
# 60641    3.871421

# %%
top_roi.index
# Out:
# Int64Index([60613, 60622, 60629, 60634, 60641], dtype='int64', name='ZipCode')

# %%
top_roi_plot = top_roi.transpose()
top_roi_plot
# Out:
# ZipCode     60613      60622      60629      60634      60641
# 2012-01  2.800758  -0.464957  -7.329343  -7.259572  -4.601941
# 2013-01  6.726716   6.504420   7.589754  10.836620  12.117835
# 2014-01  3.833597   8.019389   4.690640  14.589182  14.268834
# 2015-01  6.477232   5.379275  10.669008   6.722084   7.232349
# 2016-01  8.053622  14.866787   8.872093   5.235217   7.210999
# 2017-01  5.611739   5.969302   6.221653   3.671752   7.593036
# 2018-01  4.230416   3.888344   4.313305   3.772990   3.871421

# %%
top_roi_plot.plot(figsize=(13, 8))
plt.xlabel('Years', fontsize=16)
plt.ylabel('Percent ROI',  fontsize=16)
plt.legend(bbox_to_anchor=(1, 1), loc="best", ncol=2)
plt.title('Yearly ROI for Zip Codes with Highest ROI% in 2018',  fontsize=20)
plt.show()

# %%
date_roi.head()
# Out:
#           2012-01    2013-01   2014-01    2015-01    2016-01   2017-01  \
# ZipCode
# 60608   -2.341290  -2.285463  4.987373  12.844613  14.211499  4.908628
# 60610    4.072758  12.379611  4.776315   1.433900   4.370771  5.969273
# 60613    2.800758   6.726716  3.833597   6.477232   8.053622  5.611739
# 60614    4.972181  11.633692  7.870068   2.844454   4.234018  3.153521
# 60615   -0.811388   6.834005  5.682550   2.695844   5.904310  2.210173
#
#           2018-01
# ZipCode
# 60608   -1.051413
# 60610    0.894869
# 60613    4.230416
# 60614    1.450816
# 60615   -1.655522

# %%
# TOP Chicago Zip Codes by % ROI in 2018

plt.figure(figsize = (13,8))
plt.bar(top_roi.index, top_roi['2018-01'], color='purple')
plt.title('Chicago Zip Codes Over 3 % ROI in 2018')
plt.xlabel('Zip Code')
plt.xticks(rotation=30)
plt.ylabel('% ROI')
plt.show()

# %%
import cufflinks as cf
cf.go_offline()
top_roi_plot.iplot(title="ROI of Chicago Homes 2011-2018",
                    xTitle="Year",
                    yTitle="Percent ROI",
                   shape=(13,8),
                    subplot_titles=True,
                    fill=True,)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="36bf5bb6-280b-46ea-b956-08bea4fb0396" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("36bf5bb6-280b-46ea-b956-08bea4fb0396")) {                    Plotly.newPlot(                        "36bf5bb6-280b-46ea-b956-08bea4fb0396",                        [{"fill": "tozeroy", "fillcolor": "rgba(255, 153, 51, 0.3)", "line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60613", "text": "", "type": "scatter", "x": ["2012-01", "2013-01", "2014-01", "2015-01", "2016-01", "2017-01", "2018-01"], "y": [2.800757745815699, 6.726715931029892, 3.833596774334401, 6.477231767391565, 8.05362160210334, 5.611738733601927, 4.23041592217688]}, {"fill": "tozeroy", "fillcolor": "rgba(55, 128, 191, 0.3)", "line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60622", "text": "", "type": "scatter", "x": ["2012-01", "2013-01", "2014-01", "2015-01", "2016-01", "2017-01", "2018-01"], "y": [-0.46495682945151207, 6.504420031957481, 8.019388892914007, 5.379274692771794, 14.866786513783973, 5.969302045223869, 3.888344023048463]}, {"fill": "tozeroy", "fillcolor": "rgba(50, 171, 96, 0.3)", "line": {"color": "rgba(50, 171, 96, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60629", "text": "", "type": "scatter", "x": ["2012-01", "2013-01", "2014-01", "2015-01", "2016-01", "2017-01", "2018-01"], "y": [-7.3293429511775035, 7.589753970152549, 4.690640099200411, 10.6690083319719, 8.872092765775275, 6.221652734557732, 4.313304994957812]}, {"fill": "tozeroy", "fillcolor": "rgba(128, 0, 128, 0.3)", "line": {"color": "rgba(128, 0, 128, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60634", "text": "", "type": "scatter", "x": ["2012-01", "2013-01", "2014-01", "2015-01", "2016-01", "2017-01", "2018-01"], "y": [-7.259572260706991, 10.836620424049269, 14.589181517110866, 6.722083832225449, 5.235217249264946, 3.6717521393705455, 3.7729901813998206]}, {"fill": "tozeroy", "fillcolor": "rgba(219, 64, 82, 0.3)", "line": {"color": "rgba(219, 64, 82, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60641", "text": "", "type": "scatter", "x": ["2012-01", "2013-01", "2014-01", "2015-01", "2016-01", "2017-01", "2018-01"], "y": [-4.601940799644169, 12.117835028685473, 14.26883383624515, 7.232348516117007, 7.210999226047836, 7.593035824583076, 3.8714214467419428]}],                        {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c1 ...

# %%
# roi_clean.head()
for col in roi_clean.columns:
    if col < '2011':
        roi_clean.drop([col], inplace=True, axis=1)

roi_clean.head()
# Out:
#     ZipCode    2011    2012     2013     2014     2015     2016     2017  \
# 0     60657  732548  761040   834854   881141   918897   975076  1001805
# 3     60614  920240  965996  1078377  1163246  1196334  1246987  1286311
# 7     60640  582324  552544   576204   620609   687837   736271   776390
# 16    60647  283307  282759   321985   335174   369550   429273   457312
# 19    60618  305273  304986   346769   371575   381782   433078   461936
#
#        2018
# 0   1028402
# 3   1304973
# 7    780645
# 16   472169
# 19   460633

# %%
# roi_clean = roi_clean.set_index('ZipCode')

roi_clean = roi_clean.transpose()
roi_clean.head()
# Out:
# ZipCode   60657    60614   60640   60647   60618   60613   60629   60625  \
# 2011     732548   920240  582324  283307  305273  730588  117282  336727
# 2012     761040   965996  552544  282759  304986  751050  108686  323967
# 2013     834854  1078377  576204  321985  346769  801571  116935  355116
# 2014     881141  1163246  620609  335174  371575  832300  122420  382505
# 2015     918897  1196334  687837  369550  381782  886210  135481  387580
#
# ZipCode   60619   60610   60620   60634   60626   60649   60616   60622  \
# 2011     119229  753838  121028  185066  310492  141569  287149  533813
# 2012     109664  784540  102317  171631  298172  135486  275202  531331
# 2013     104776  881663  103567  190230  321955  150631  314009  565891
# 2014     112213  923774   96370  217983  354376  154933  324161  611272
# 2015     118970  937020  109320  232636  360372  154898  319176  644154
#
# ZipCode   60615   60641   60660   60608
# 2011     370846  184357  409437  174690
# 2012     367837  175873  394843  170600
# 2013     392975  197185  420154  166701
# 2014     415306  225321  446199  175015
# 2015     426502  241617  482400  197495

# %%
# roi_clean = roi_clean.loc([roi_clean['ZipCode']==60613] |
#                           [roi_clean['ZipCode']==60622] |
#                           [roi_clean['ZipCode']==60629] |
#                           [roi_clean['ZipCode']==60634] |
#                           [roi_clean['ZipCode']==60641])


top_roi_list = [60613, 60622, 60629, 60634, 60641]

for col in roi_clean:
    if col not in top_roi_list:
        roi_clean.drop([col], inplace=True, axis=1)
        
    
roi_clean.head()
# Out:
# ZipCode   60613   60629   60634   60622   60641
# 2011     730588  117282  185066  533813  184357
# 2012     751050  108686  171631  531331  175873
# 2013     801571  116935  190230  565891  197185
# 2014     832300  122420  217983  611272  225321
# 2015     886210  135481  232636  644154  241617

# %%
roi_clean.iplot(title="Value of Chicago Homes 2011-2018",
                    xTitle="Year",
                    yTitle="Home Values",
                   shape=(13,8),
#                     subplot_titles=True,
                    fill=True,)
# Out:
# <div>                            <div id="33020d2a-8aeb-4e43-81ec-c8860b02e122" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';                                    if (document.getElementById("33020d2a-8aeb-4e43-81ec-c8860b02e122")) {                    Plotly.newPlot(                        "33020d2a-8aeb-4e43-81ec-c8860b02e122",                        [{"fill": "tozeroy", "fillcolor": "rgba(255, 153, 51, 0.3)", "line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60613", "text": "", "type": "scatter", "x": ["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"], "y": [730588, 751050, 801571, 832300, 886210, 957582, 1011319, 1054102]}, {"fill": "tozeroy", "fillcolor": "rgba(55, 128, 191, 0.3)", "line": {"color": "rgba(55, 128, 191, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60629", "text": "", "type": "scatter", "x": ["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"], "y": [117282, 108686, 116935, 122420, 135481, 147501, 156678, 163436]}, {"fill": "tozeroy", "fillcolor": "rgba(50, 171, 96, 0.3)", "line": {"color": "rgba(50, 171, 96, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60634", "text": "", "type": "scatter", "x": ["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"], "y": [185066, 171631, 190230, 217983, 232636, 244815, 253804, 263380]}, {"fill": "tozeroy", "fillcolor": "rgba(128, 0, 128, 0.3)", "line": {"color": "rgba(128, 0, 128, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60622", "text": "", "type": "scatter", "x": ["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"], "y": [533813, 531331, 565891, 611272, 644154, 739919, 784087, 814575]}, {"fill": "tozeroy", "fillcolor": "rgba(219, 64, 82, 0.3)", "line": {"color": "rgba(219, 64, 82, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "mode": "lines", "name": "60641", "text": "", "type": "scatter", "x": ["2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"], "y": [184357, 175873, 197185, 225321, 241617, 259040, 278709, 289499]}],                        {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.44444444444 ...

# %% [markdown]
# #### This below is to check our model against actual top 5 - if needed.

# %%
top_2018 = top_zips_df.groupby('ZipCode')['2018-01'].mean().sort_values(ascending=False)
top_2018.head()
# Out:
# ZipCode
# 60614    1302700
# 60613    1051300
# 60610    1050800
# 60657    1024400
# 60622     819300
# Name: 2018-01, dtype: int64

# %% [markdown]
# # DON'T TOUCH THIS GRAPH -

# %%
# # fun.plot(plot_df)
# plot_df.plot(figsize=(13, 8))
# plt.title('Home Values for Highest Urbanized Zip Codes 2011-2018')
# plt.xlabel('Years')
# plt.ylabel('Home Value')
# plt.show()

# %% [markdown]
# ### Note on graph above!
# - We notice a zip code here that does not have values before 2013 -
# - I decided here to discard of this zip code as well
# - It was zip code 60611
# - I then went back and re-filtered my urbanized zip codes to get back to 20

# %% [markdown]
# # Future Work:
# - Mapping ROI or average home values for all states and picking a few for future work

# %%
z_df = pd.read_csv('zillow_data.csv')
z_df.head()
# Out:
#    RegionID  RegionName      City State              Metro CountyName  \
# 0     84654       60657   Chicago    IL            Chicago       Cook
# 1     90668       75070  McKinney    TX  Dallas-Fort Worth     Collin
# 2     91982       77494      Katy    TX            Houston     Harris
# 3     84616       60614   Chicago    IL            Chicago       Cook
# 4     93144       79936   El Paso    TX            El Paso    El Paso
#
#    SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 0         1  334200.0  335400.0  336500.0  ...  1005500  1007500  1007800
# 1         2  235700.0  236900.0  236700.0  ...   308000   310000   312500
# 2         3  210400.0  212200.0  212200.0  ...   321000   320600   320200
# 3         4  498100.0  500900.0  503100.0  ...  1289800  1287700  1287400
# 4         5   77300.0   77300.0   77300.0  ...   119100   119400   120000
#
#    2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1009600  1013300  1018700  1024400  1030700  1033800  1030600
# 1   314100   315000   316600   318100   319600   321100   321800
# 2   320400   320800   321200   321200   323000   326900   329900
# 3  1291500  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120300   120500   121000   121500
#
# [5 rows x 272 columns]

# %%
z_df.drop(['RegionID', 'SizeRank'], inplace=True, axis=1)
z_df.rename({'RegionName': 'ZipCode'}, inplace=True, axis=1)
z_df.head()
# Out:
#    ZipCode      City State              Metro CountyName   1996-04   1996-05  \
# 0    60657   Chicago    IL            Chicago       Cook  334200.0  335400.0
# 1    75070  McKinney    TX  Dallas-Fort Worth     Collin  235700.0  236900.0
# 2    77494      Katy    TX            Houston     Harris  210400.0  212200.0
# 3    60614   Chicago    IL            Chicago       Cook  498100.0  500900.0
# 4    79936   El Paso    TX            El Paso    El Paso   77300.0   77300.0
#
#     1996-06   1996-07   1996-08  ...  2017-07  2017-08  2017-09  2017-10  \
# 0  336500.0  337600.0  338500.0  ...  1005500  1007500  1007800  1009600
# 1  236700.0  235400.0  233300.0  ...   308000   310000   312500   314100
# 2  212200.0  210700.0  208300.0  ...   321000   320600   320200   320400
# 3  503100.0  504600.0  505500.0  ...  1289800  1287700  1287400  1291500
# 4   77300.0   77300.0   77400.0  ...   119100   119400   120000   120300
#
#    2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 0  1013300  1018700  1024400  1030700  1033800  1030600
# 1   315000   316600   318100   319600   321100   321800
# 2   320800   321200   321200   323000   326900   329900
# 3  1296600  1299000  1302700  1306400  1308500  1307000
# 4   120300   120300   120300   120500   121000   121500
#
# [5 rows x 270 columns]

# %%
year_list = ['1996', '1997','1998', '1999','2000', '2001','2002',
             '2003','2004','2005','2006','2007','2008','2009',
             '2010','2011', '2012', '2013', '2014', '2015', 
             '2016', '2017', '2018']

# %%
for year in year_list:
    fun.get_mean_year(z_df, year)
z_df.head()
# Out:
#    ZipCode      City State              Metro CountyName   1996-04   1996-05  \
# 0    60657   Chicago    IL            Chicago       Cook  334200.0  335400.0
# 1    75070  McKinney    TX  Dallas-Fort Worth     Collin  235700.0  236900.0
# 2    77494      Katy    TX            Houston     Harris  210400.0  212200.0
# 3    60614   Chicago    IL            Chicago       Cook  498100.0  500900.0
# 4    79936   El Paso    TX            El Paso    El Paso   77300.0   77300.0
#
#     1996-06   1996-07   1996-08  ...     2009    2010    2011    2012  \
# 0  336500.0  337600.0  338500.0  ...   790743  760244  732548  761040
# 1  236700.0  235400.0  233300.0  ...   200541  202565  200512  202546
# 2  212200.0  210700.0  208300.0  ...   247111  249808  248614  252865
# 3  503100.0  504600.0  505500.0  ...  1014667  964985  920240  965996
# 4   77300.0   77300.0   77400.0  ...   119277  117199  116257  112822
#
#       2013     2014     2015     2016     2017     2018
# 0   834854   881141   918897   975076  1001805  1028402
# 1   216866   239914   265287   289402   308137   319473
# 2   263787   289639   312899   327232   321016   325085
# 3  1078377  1163246  1196334  1246987  1286311  1304973
# 4   112942   113256   115436   114869   118866   120712
#
# [5 rows x 293 columns]

# %%
for col in z_df:
    if '-' in col:
        z_df.drop([col], inplace=True, axis=1)
z_df.head()
# Out:
#    ZipCode      City State              Metro CountyName    1996    1997  \
# 0    60657   Chicago    IL            Chicago       Cook  345921  352942
# 1    75070  McKinney    TX  Dallas-Fort Worth     Collin  231968  199120
# 2    77494      Katy    TX            Houston     Harris  207983  200200
# 3    60614   Chicago    IL            Chicago       Cook  512123  499496
# 4    79936   El Paso    TX            El Paso    El Paso   77930   77951
#
#      1998    1999    2000  ...     2009    2010    2011    2012     2013  \
# 0  396505  466646  565227  ...   790743  760244  732548  761040   834854
# 1  205268  197423  222005  ...   200541  202565  200512  202546   216866
# 2  240144  300724  319794  ...   247111  249808  248614  252865   263787
# 3  561259  651321  750713  ...  1014667  964985  920240  965996  1078377
# 4   79209   81062   82440  ...   119277  117199  116257  112822   112942
#
#       2014     2015     2016     2017     2018
# 0   881141   918897   975076  1001805  1028402
# 1   239914   265287   289402   308137   319473
# 2   289639   312899   327232   321016   325085
# 3  1163246  1196334  1246987  1286311  1304973
# 4   113256   115436   114869   118866   120712
#
# [5 rows x 28 columns]

# %%
z_df['2012-01'] = fun.get_return_rate('2011', '2012', z_df)
z_df['2013-01'] = fun.get_return_rate('2012', '2013', z_df)
z_df['2014-01'] = fun.get_return_rate('2013', '2014', z_df) 
z_df['2015-01'] = fun.get_return_rate('2014', '2015', z_df)
z_df['2016-01'] = fun.get_return_rate('2015', '2016', z_df) 
z_df['2017-01'] = fun.get_return_rate('2016', '2017', z_df) 
z_df['2018-01'] = fun.get_return_rate('2017', '2018', z_df) 
z_df.drop(['2011', '2012', '2013', '2014', '2015', '2016', '2017',
       '2018'], inplace=True, axis=1)
z_df.head()
# Out:
#    ZipCode      City State              Metro CountyName    1996    1997  \
# 0    60657   Chicago    IL            Chicago       Cook  345921  352942
# 1    75070  McKinney    TX  Dallas-Fort Worth     Collin  231968  199120
# 2    77494      Katy    TX            Houston     Harris  207983  200200
# 3    60614   Chicago    IL            Chicago       Cook  512123  499496
# 4    79936   El Paso    TX            El Paso    El Paso   77930   77951
#
#      1998    1999    2000  ...     2008     2009    2010   2012-01    2013-01  \
# 0  396505  466646  565227  ...   849341   790743  760244  3.889438   9.699096
# 1  205268  197423  222005  ...   208197   200541  202565  1.014403   7.069999
# 2  240144  300724  319794  ...   249110   247111  249808  1.709880   4.319301
# 3  561259  651321  750713  ...  1118739  1014667  964985  4.972181  11.633692
# 4   79209   81062   82440  ...   126221   119277  117199 -2.954661   0.106362
#
#      2014-01    2015-01   2016-01   2017-01   2018-01
# 0   5.544323   4.284899  6.113743  2.741222  2.654908
# 1  10.627761  10.575873  9.090155  6.473694  3.678883
# 2   9.800331   8.030686  4.580711 -1.899570  1.267538
# 3   7.870068   2.844454  4.234018  3.153521  1.450816
# 4   0.278019   1.924843 -0.491181  3.479616  1.553009
#
# [5 rows x 27 columns]

# %%
z_df.drop(['1996', '1997', '1998', '1999', '2000', '2001', '2002',
       '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010'], inplace=True, axis=1)
z_df.head()
# Out:
#    ZipCode      City State              Metro CountyName   2012-01    2013-01  \
# 0    60657   Chicago    IL            Chicago       Cook  3.889438   9.699096
# 1    75070  McKinney    TX  Dallas-Fort Worth     Collin  1.014403   7.069999
# 2    77494      Katy    TX            Houston     Harris  1.709880   4.319301
# 3    60614   Chicago    IL            Chicago       Cook  4.972181  11.633692
# 4    79936   El Paso    TX            El Paso    El Paso -2.954661   0.106362
#
#      2014-01    2015-01   2016-01   2017-01   2018-01
# 0   5.544323   4.284899  6.113743  2.741222  2.654908
# 1  10.627761  10.575873  9.090155  6.473694  3.678883
# 2   9.800331   8.030686  4.580711 -1.899570  1.267538
# 3   7.870068   2.844454  4.234018  3.153521  1.450816
# 4   0.278019   1.924843 -0.491181  3.479616  1.553009

# %%
# map_df = pd.DataFrame()
# map_df['State'] = z_df['State']
# map_df['2018-04'] = z_df['2018-04']
# map_df['2017-04'] = z_df['2017-04']
# map_df.head()

# %%
map_df['2018-04-01'] = fun.get_return_rate('2017-04', '2018-04', map_df)
map_df.head()
# Out:
#   State  2018-04  2017-04  2018-04-01
# 0    IL  1030600   989200    4.185200
# 1    TX   321800   304400    5.716163
# 2    TX   329900   320000    3.093750
# 3    IL  1307000  1282500    1.910331
# 4    TX   121500   118000    2.966102

# %%
states = map_df.groupby('State').mean()
states.head()
# Out:
#              2018-04        2017-04  2018-04-01
# State
# AK     323046.428571  316089.285714    2.216190
# AL     157033.879781  147797.267760    6.503329
# AR     137620.000000  129865.714286    6.529845
# AZ     271952.173913  252921.739130    8.283342
# CA     746329.084967  677681.944444    9.793955

# %%
states.reset_index(inplace=True)
states.head()
# Out:
#   State        2018-04        2017-04  2018-04-01
# 0    AK  323046.428571  316089.285714    2.216190
# 1    AL  157033.879781  147797.267760    6.503329
# 2    AR  137620.000000  129865.714286    6.529845
# 3    AZ  271952.173913  252921.739130    8.283342
# 4    CA  746329.084967  677681.944444    9.793955

# %%
states.sort_values('2018-04-01', ascending=False).head()
# Out:
#    State        2018-04        2017-04  2018-04-01
# 33    NV  329420.388350  293400.000000   14.208562
# 47    WA  408570.381232  363562.756598   11.804520
# 44    UT  317001.652893  288475.206612   10.271495
# 4     CA  746329.084967  677681.944444    9.793955
# 9     FL  288191.592357  268317.452229    9.581948

# %%
fig = px.choropleth(states, locations='State', locationmode='USA-states',
                    color='2018-04-01', scope='usa', color_continuous_scale='Purples', 
            title='Percent Yearly Average ROI by State')
fig.show()
# Out:
# <div>                            <div id="cf10790f-bb1b-4f33-a241-5cf79de1a2f3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf10790f-bb1b-4f33-a241-5cf79de1a2f3")) {                    Plotly.newPlot(                        "cf10790f-bb1b-4f33-a241-5cf79de1a2f3",                        [{"coloraxis": "coloraxis", "geo": "geo", "hovertemplate": "State=%{location}<br>2018-04-01=%{z}<extra></extra>", "locationmode": "USA-states", "locations": ["AK", "AL", "AR", "AZ", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "IA", "ID", "IL", "IN", "KS", "KY", "LA", "MA", "MD", "ME", "MI", "MN", "MO", "MS", "MT", "NC", "ND", "NE", "NH", "NJ", "NM", "NV", "NY", "OH", "OK", "OR", "PA", "RI", "SC", "SD", "TN", "TX", "UT", "VA", "VT", "WA", "WI", "WV", "WY"], "name": "", "type": "choropleth", "z": [2.216190437269914, 6.503329232390398, 6.529844617891859, 8.283341827526257, 9.793954521967187, 8.550363504925436, 3.255073365945529, 5.508695886152638, 3.628643752557886, 9.581948488313735, 7.443624947081408, 6.758920962320043, 3.151098298870633, 7.963510860666534, 3.5990857311700526, 7.8004136242649835, 3.7808124487319374, 6.316542364168292, 3.142831305010688, 6.917567044318188, 5.36984873536889, 7.4783456208479615, 7.926254381693683, 6.408478619948481, 6.603116551496218, 3.488831298415465, 5.2431884920227985, 6.010393944562171, 1.5657284381308385, 8.54535660490005, 7.6007554913781, 8.40690796235562, 5.584711487428802, 14.208562391559974, 6.036004663634746, 6.84727775083763, 6.889086103205591, 8.744159452536836, 5.986972666456713, 8.889648960742923, 7.573647475895923, 6.7669136846803255, 9.12696617440305, 6.5481955657906115, 10.271495316532347, 4.04632234707092, 1.2532284259312434, 11.804520393432972, 6.049500729465419, 3.636559725243512, 3.7911764209206082]}],                        {"coloraxis": {"colorbar": {"title": {"text": "2018-04-01"}}, "colorscale": [[0.0, "rgb(252,251,253)"], [0.125, "rgb(239,237,245)"], [0.25, "rgb(218,218,235)"], [0.375, "rgb(188,189,220)"], [0.5, "rgb(158,154,200)"], [0.625, "rgb(128,125,186)"], [0.75, "rgb(106,81,163)"], [0.875, "rgb(84,39,143)"], [1.0, "rgb(63,0,125)"]]}, "geo": {"center": {}, "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "scope": "usa"}, "legend": {"tracegroupgap": 0}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "ty ...
